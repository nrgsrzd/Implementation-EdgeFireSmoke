# %% [markdown]
# #Packages

# %%
import tensorflow as tf
import os, fnmatch
import PIL
import numpy as np
import h5py
from sklearn.metrics import multilabel_confusion_matrix
from sklearn.metrics import confusion_matrix
from sklearn.metrics import hamming_loss
from sklearn.metrics import classification_report
from sklearn import metrics
from sklearn.model_selection import train_test_split
import keras
import matplotlib.pyplot as plt
from keras.models import Sequential
from tensorflow.keras.layers import Conv2D
from keras.layers import MaxPooling2D, Flatten, Dense, Dropout
from keras.initializers import GlorotUniform
from keras.regularizers import l2

# %% [markdown]
# #Import data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Displaying the contents of the text file
file = open("/content/drive/MyDrive/Image/testData.txt", "r")
# content = file.read()
# print(type(content))
Lines = file.readlines()
testData = []
testLabel = []
count = 0
# Strips the newline character
for line in Lines:
    count += 1
    print(line)
    testData.append(line)
file.close()

file = open("/content/drive/MyDrive/Image/testLabel.txt", "r")
# content = file.read()
    # testLabel.append(line)
Lines = file.readlines()
for line in Lines:
    count += 1
    print(line)

    testLabel.append(line)
    # print("Line{}: {}".format(count, line.strip()))
 
# print("\nContent in file1.txt:\n", content)
file.close()
# Out:
# Streaming output truncated to the last 5000 lines.
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/p (2).png
#
# /content/drive/MyDrive/Image/Dataset2/fog-area/scene06961.png
#
# /content/drive/MyDrive/Image/Dataset2/fog-area/8 (73).png
#
# /content/drive/MyDrive/Image/Dataset2/fog-area/9 (27).png
#
# /content/drive/MyDrive/Image/Dataset2/burned-area/u (39).png
#
# /content/drive/MyDrive/Image/Dataset2/burned-area/scene02681.png
#
# /content/drive/MyDrive/Image/Dataset2/burned-area/q (203).png
#
# /content/drive/MyDrive/Image/Dataset2/green-area/5 (16).png
#
# /content/drive/MyDrive/Image/Dataset2/green-area/scene04321.png
#
# /content/drive/MyDrive/Image/Dataset2/burned-area/t (49).png
#
# /content/drive/MyDrive/Image/Dataset2/burned-area/u (41).png
#
# /content/drive/MyDrive/Image/Dataset2/burned-area/r (10).png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/scene00761.png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/9 (72).png
#
# /content/drive/MyDrive/Image/Dataset2/burned-area/t (1).png
#
# /content/drive/MyDrive/Image/Dataset2/fog-area/scene05121.png
#
# /content/drive/MyDrive/Image/Dataset2/burned-area/u (176).png
#
# /content/drive/MyDrive/Image/Dataset2/green-area/4 (51).png
#
# /content/drive/MyDrive/Image/Dataset2/green-area/11 (46).png
#
# /content/drive/MyDrive/Image/Dataset2/burned-area/o (40).png
#
# /content/drive/MyDrive/Image/Dataset2/green-area/12 (24).png
#
# /content/drive/MyDrive/Image/Dataset2/green-area/8 (40).png
#
# /content/drive/MyDrive/Image/Dataset2/fog-area/3 (89).png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/scene00921.png
#
# /content/drive/MyDrive/Image/Dataset2/green-area/4 (12).png
#
# /content/drive/MyDrive/Image/Dataset2/burned-area/o (157).png
#
# /content/drive/MyDrive/Image/Dataset2/fog-area/8 (11).png
#
# /content/drive/MyDrive/Image/Dataset2/green-area/3 (22).png
#
# /content/drive/MyDrive/Image/Dataset2/fog-area/2 (1).png
#
# /content/drive/MyDrive/Image/Dataset2/green-area/5 (10).png
#
# /content/drive/MyDrive/Image/Dataset2/green-area/10 (50).png
#
# /content/drive/MyDrive/Image/Dataset2/burned-area/o (63).png
#
# /content/drive/MyDrive/Image/Dataset2/green-area/6 (22).png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/a (38).png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/15 (55).png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/p (71).png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/11 (105).png
#
# /content/drive/MyDrive/Image/Dataset2/burned-area/u (66).png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/10 (72).png
#
# /content/drive/MyDrive/Image/Dataset2/fog-area/scene08921.png
#
# /content/drive/MyDrive/Image/Dataset2/burned-area/o (160).png
#
# /content/drive/MyDrive/Image/Dataset2/burned-area/u (100).png
#
# /content/drive/MyDrive/Image/Dataset2/burned-area/u (101).png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/s (7).png
#
# /content/drive/MyDrive/Image/Dataset2/green-area/scene00161.png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/16 (7).png
#
# /content/drive/MyDrive/Image/Dataset2/fog-area/11 (6).png
#
# /content/drive/MyDrive/Image/Dataset2/fog-area/3 (149).png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/a (98).png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/9 (215).png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/11 (137).png
#
# /content/drive/MyDrive/Image/Dataset2/burned-area/o (29).png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/a (69).png
#
# /content/drive/MyDrive/Image/Dataset2/fog-area/scene02961.png
#
# /content/drive/MyDrive/Image/Dataset2/burned-area/y (23).png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/p (47).png
#
# /content/drive/MyDrive/Image/Dataset2/burned-area/q (234).png
#
# /content/drive/MyDrive/Image/Dataset2/fog-area/2 (30).png
#
# /content/drive/MyDrive/Image/Dataset2/green-area/11 (11).png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/scene00121.png
#
# /content/drive/MyDrive/Image/Dataset2/fog-area/3 (141).png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/9 (317).png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/g (27).png
#
# /content/drive/MyDrive/Image/Dataset2/burned-area/o (340).png
#
# /content/drive/MyDrive/Image/Dataset2/green-area/10 (26).png
#
# /content/drive/MyDrive/Image/Dataset2/fog-area/3 (56).png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/8 (40).png
#
# /content/drive/MyDrive/Image/Dataset2/green-area/7 (49).png
#
# /content/drive/MyDrive/Image/Dataset2/green-area/scene01481.png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/15 (69).png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/a (97).png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/13 (4).png
#
# /content/drive/MyDrive/Image/Dataset2/burned-area/o (150).png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/8 (155).png
#
# /content/drive/MyDrive/Image/Dataset2/green-area/8 (58).png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/9 (118).png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/8 (105).png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/p (117).png
#
# /content/drive/MyDrive/Image/Dataset2/burned-area/u (14).png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/10 (58).png
#
# /content/drive/MyDrive/Image/Dataset2/burned-area/y (19).png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/p (57).png
#
# /content/drive/MyDrive/Image/Dataset2/burned-area/r (29).png
#
# /content/drive/MyDrive/Image/Dataset2/fog-area/9 (31).png
#
# /content/drive/MyDrive/Image/Dataset2/green-area/scene02121.png
#
# /content/drive/MyDrive/Image/Dataset2/burned-area/y (61).png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/14 (52).png
#
# /content/drive/MyDrive/Image/Dataset2/burned-area/q (202).png
#
# /content/drive/MyDrive/Image/Dataset2/burned-area/o (222).png
#
# /content/drive/MyDrive/Image/Dataset2/burned-area/scene01241.png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/p (39).png
#
# /content/drive/MyDrive/Image/Dataset2/fog-area/scene06761.png
#
# /content/drive/MyDrive/Image/Dataset2/green-area/scene05601.png
#
# /content/drive/MyDrive/Image/Dataset2/burned-area/o (233).png
#
# /content/drive/MyDrive/Image/Dataset2/burned-area/q (194).png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/scene01361.png
#
# /content/drive/MyDrive/Image/Dataset2/green-area/6 (24).png
#
# /content/drive/MyDrive/Image/Dataset2/fog-area/10 (97).png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/g (26).png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/g (23).png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/scene02641.png
#
# /content/drive/MyDrive/Image/Dataset2/fog-area/scene02001.png
#
# /content/drive/MyDrive/Image/Dataset2/green-area/10 (2).png
#
# /content/drive/MyDrive/Image/Dataset2/fog-area/7 (18).png
#
# /content/drive/MyDrive/Image/Dataset2/green-area/7 (5).png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/15 (60).png
#
# /content/drive/MyDrive/Image/Dataset2/burned-area/u (3).png
#
# /content/drive/MyDrive/Image/Dataset2/burned-area/y (46).png
#
# /content/drive/MyDrive/Image/Dataset2/green-area/8 (50).png
#
# /content/drive/MyDrive/Image/Dataset2/fog-area/3 (28).png
#
# /content/drive/MyDrive/Image/Dataset2/burned-area/q (220).png
#
# /content/drive/MyDrive/Image/Dataset2/fog-area/scene05401.png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/12 (11).png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/9 (163).png
#
# /content/drive/MyDrive/Image/Dataset2/fog-area/scene08641.png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/a (83).png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/p (124).png
#
# /content/drive/MyDrive/Image/Dataset2/green-area/10 (6).png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/9 (291).png
#
# /content/drive/MyDrive/Image/Dataset2/fog-area/4 (45).png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/10 (115).png
#
# /content/drive/MyDrive/Image/Dataset2/green-area/4 (8).png
#
# /content/drive/MyDrive/Image/Dataset2/fog-area/4 (62).png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/11 (46).png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/12 (3).png
#
# /content/drive/MyDrive/Image/Dataset2/burned-area/o (80).png
#
# /content/drive/MyDrive/Image/Dataset2/green-area/6 (7).png
#
# /content/drive/MyDrive/Image/Dataset2/burned-area/u (75).png
#
# /content/drive/MyDrive/Image/Dataset2/burned-area/u (43).png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/p (88).png
#
# /content/drive/MyDrive/Image/Dataset2/green-area/scene09281.png
#
# /content/drive/MyDrive/Image/Dataset2/burned-area/e (5).png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/8 (77).png
#
# /content/drive/MyDrive/Image/Dataset2/fog-area/scene08841.png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/g (57).png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/scene01881.png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/14 (74).png
#
# /content/drive/MyDrive/Image/Dataset2/burned-area/o (278).png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/9 (150).png
#
# /content/drive/MyDrive/Image/Dataset2/fog-area/3 (168).png
#
# /content/drive/MyDrive/Image/Dataset2/burned-area/o (119).png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/scene03481.png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/p (30).png
#
# /content/drive/MyDrive/Image/Dataset2/fog-area/9 (66).png
#
# /content/drive/MyDrive/Image/Dataset2/burned-area/q (109).png
#
# /content/drive/MyDrive/Image/Dataset2/burned-area/u (88).png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/a (87).png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/a (82).png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/9 (253).png
#
# /content/drive/MyDrive/Image/Dataset2/green-area/scene01281.png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/16 (2).png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/14 (6).png
#
# /content/drive/MyDrive/Image/Dataset2/burned-area/o (145).png
#
# /content/drive/MyDrive/Image/Dataset2/green-area/11 (13).png
#
# /content/drive/MyDrive/Image/Dataset2/fog-area/5 (4).png
#
# /content/drive/MyDrive/Image/Dataset2/burned-area/y (75).png
#
# /content/drive/MyDrive/Image/Dataset2/burned-area/w (1).png
#
# /content/drive/MyDrive/Image/Dataset2/fog-area/11 (9).png
#
# /content/drive/MyDrive/Image/Dataset2/burned-area/u (47).png
#
# /content/drive/MyDrive/Image/Dataset2/fog-area/4 (28).png
#
# /content/drive/MyDrive/Image/Dataset2/green-area/8 (68).png
#
# /content/drive/MyDrive/Image/Dataset2/green-area/8 (8).png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/a (40).png
#
# /content/drive/MyDrive/Image/Dataset2/fog-area/scene00801.png
#
# /content/drive/MyDrive/Image/Dataset2/fog-area/7 (2).png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/9 (138).png
#
# /content/drive/MyDrive/Image/Dataset2/burned-area/o (234).png
#
# /content/drive/MyDrive/Image/Dataset2/burned-area/q (149).png
#
# /content/drive/MyDrive/Image/Dataset2/burned-area/o (185).png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/9 (314).png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/g (67).png
#
# /content/drive/MyDrive/Image/Dataset2/fog-area/scene03881.png
#
# /content/drive/MyDrive/Image/Dataset2/green-area/6 (45).png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/9 (124).png
#
# /content/drive/MyDrive/Image/Dataset2/burned-area/o (342).png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/p (125).png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/14 (59).png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/11 (94).png
#
# /content/drive/MyDrive/Image/Dataset2/green-area/10 (33).png
#
# /content/drive/MyDrive/Image/Dataset2/burned-area/q (78).png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/9 (195).png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/g (40).png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/g (54).png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/14 (55).png
#
# /content/drive/MyDrive/Image/Dataset2/burned-area/u (161).png
#
# /content/drive/MyDrive/Image/Dataset2/burned-area/u (51).png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/p (4).png
#
# /content/drive/MyDrive/Image/Dataset2/burned-area/y (41).png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/8 (64).png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/9 (55).png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/g (6).png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/9 (282).png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/8 (71).png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/11 (15).png
#
# /content/drive/MyDrive/Image/Dataset2/fog-area/5 (25).png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/s (19).png
#
# /content/drive/MyDrive/Image/Dataset2/fog-area/9 (10).png
#
# /content/drive/MyDrive/Image/Dataset2/burned-area/q (139).png
#
# /content/drive/MyDrive/Image/Dataset2/green-area/8 (21).png
#
# /content/drive/MyDrive/Image/Dataset2/burned-area/q (5).png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/9 (82).png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/8 (115).png
#
# /content/drive/MyDrive/Image/Dataset2/burned-area/q (90).png
#
# /content/drive/MyDrive/Image/Dataset2/fog-area/scene02721.png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/g (25).png
#
# /content/drive/MyDrive/Image/Dataset2/fog-area/5 (14).png
#
# /content/drive/MyDrive/Image/Dataset2/fog-area/10 (63).png
#
# /content/drive/MyDrive/Image/Dataset2/green-area/scene07001.png
#
# /content/drive/MyDrive/Image/Dataset2/green-area/scene07801.png
#
# /content/drive/MyDrive/Image/Dataset2/green-area/12 (56).png
#
# /content/drive/MyDrive/Image/Dataset2/green-area/4 (46).png
#
# /content/drive/MyDrive/Image/Dataset2/burned-area/u (140).png
#
# /content/drive/MyDrive/Image/Dataset2/burned-area/q (61).png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/11 (170).png
#
# /content/drive/MyDrive/Image/Dataset2/burned-area/y (27).png
#
# /content/drive/MyDrive/Image/Dataset2/green-area/8 (15).png
#
# /content/drive/MyDrive/Image/Dataset2/fog-area/scene06281.png
#
# /content/drive/MyDrive/Image/Dataset2/burned-area/o (96).png
#
# /content/drive/MyDrive/Image/Dataset2/burned-area/o (143).png
#
# /content/drive/MyDrive/Image/Dataset2/green-area/scene00801.png
#
# /content/drive/MyDrive/Image/Dataset2/burned-area/q (76).png
#
# /content/drive/MyDrive/Image/Dataset2/fog-area/3 (70).png
#
# /content/drive/MyDrive/Image/Dataset2/burned-area/o (315).png
#
# /content/drive/MyDrive/Image/Dataset2/burned-area/o (4).png
#
# /content/drive/MyDrive/Image/Dataset2/green-area/scene02201.png
#
# /content/drive/MyDrive/Image/Dataset2/burned-area/t (54).png
#
# /content/drive/MyDrive/Image/Dataset2/burned-area/y (25).png
#
# /content/drive/MyDrive/Image/Dataset2/burned-area/e (32).png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/p (50).png
#
# /content/drive/MyDrive/Image/Dataset2/burned-area/o (69).png
#
# /content/drive/MyDrive/Image/Dataset2/burned-area/e (10).png
#
# /content/drive/MyDrive/Image/Dataset2/fog-area/scene01721.png
#
# /content/drive/MyDrive/Image/Dataset2/fog-area/10 (34).png
#
# /content/drive/MyDrive/Image/Dataset2/green-area/7 (32).png
#
# /content/drive/MyDrive/Image/Dataset2/fog-area/8 (71).png
#
# /content/drive/MyDrive/Image/Dataset2/green-area/scene03401.png
#
# /content/drive/MyDrive/Image/Dataset2/green-area/10 (57).png
#
# /content/drive/MyDrive/Image/Dataset2/burned-area/u (22).png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/15 (28).png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/9 (111).png
#
# /content/drive/MyDrive/Image/Dataset2/fog-area/4 (21).png
#
# /content/drive/MyDrive/Image/Dataset2/green-area/scene02841.png
#
# /content/drive/MyDrive/Image/Dataset2/green-area/5 (90).png
#
# /content/drive/MyDrive/Image/Dataset2/green-area/scene06201.png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/9 (25).png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/a (80).png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/8 (37).png
#
# /content/drive/MyDrive/Image/Dataset2/green-area/12 (44).png
#
# /content/drive/MyDrive/Image/Dataset2/burned-area/y (68).png
#
# /content/drive/MyDrive/Image/Dataset2/green-area/5 (28).png
#
# /content/drive/MyDrive/Image/Dataset2/fog-area/3 (60).png
#
# /content/drive/MyDrive/Image/Dataset2/green-area/scene03281.png
#
# /content/drive/MyDrive/Image/Dataset2/fog-area/2 
png
#
# /content/drive/MyDrive/Image/Dataset2/burned-area/o (222).png
#
# /content/drive/MyDrive/Image/Dataset2/burned-area/scene01241.png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/p (39).png
#
# /content/drive/MyDrive/Image/Dataset2/fog-area/scene06761.png
#
# /content/drive/MyDrive/Image/Dataset2/green-area/scene05601.png
#
# /content/drive/MyDrive/Image/Dataset2/burned-area/o (233).png
#
# /content/drive/MyDrive/Image/Dataset2/burned-area/q (194).png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/scene01361.png
#
# /content/drive/MyDrive/Image/Dataset2/green-area/6 (24).png
#
# /content/drive/MyDrive/Image/Dataset2/fog-area/10 (97).png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/g (26).png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/g (23).png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/scene02641.png
#
# /content/drive/MyDrive/Image/Dataset2/fog-area/scene02001.png
#
# /content/drive/MyDrive/Image/Dataset2/green-area/10 (2).png
#
# /content/drive/MyDrive/Image/Dataset2/fog-area/7 (18).png
#
# /content/drive/MyDrive/Image/Dataset2/green-area/7 (5).png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/15 (60).png
#
# /content/drive/MyDrive/Image/Dataset2/burned-area/u (3).png
#
# /content/drive/MyDrive/Image/Dataset2/burned-area/y (46).png
#
# /content/drive/MyDrive/Image/Dataset2/green-area/8 (50).png
#
# /content/drive/MyDrive/Image/Dataset2/fog-area/3 (28).png
#
# /content/drive/MyDrive/Image/Dataset2/burned-area/q (220).png
#
# /content/drive/MyDrive/Image/Dataset2/fog-area/scene05401.png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/12 (11).png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/9 (163).png
#
# /content/drive/MyDrive/Image/Dataset2/fog-area/scene08641.png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/a (83).png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/p (124).png
#
# /content/drive/MyDrive/Image/Dataset2/green-area/10 (6).png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/9 (291).png
#
# /content/drive/MyDrive/Image/Dataset2/fog-area/4 (45).png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/10 (115).png
#
# /content/drive/MyDrive/Image/Dataset2/green-area/4 (8).png
#
# /content/drive/MyDrive/Image/Dataset2/fog-area/4 (62).png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/11 (46).png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/12 (3).png
#
# /content/drive/MyDrive/Image/Dataset2/burned-area/o (80).png
#
# /content/drive/MyDrive/Image/Dataset2/green-area/6 (7).png
#
# /content/drive/MyDrive/Image/Dataset2/burned-area/u (75).png
#
# /content/drive/MyDrive/Image/Dataset2/burned-area/u (43).png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/p (88).png
#
# /content/drive/MyDrive/Image/Dataset2/green-area/scene09281.png
#
# /content/drive/MyDrive/Image/Dataset2/burned-area/e (5).png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/8 (77).png
#
# /content/drive/MyDrive/Image/Dataset2/fog-area/scene08841.png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/g (57).png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/scene01881.png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/14 (74).png
#
# /content/drive/MyDrive/Image/Dataset2/burned-area/o (278).png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/9 (150).png
#
# /content/drive/MyDrive/Image/Dataset2/fog-area/3 (168).png
#
# /content/drive/MyDrive/Image/Dataset2/burned-area/o (119).png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/scene03481.png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/p (30).png
#
# /content/drive/MyDrive/Image/Dataset2/fog-area/9 (66).png
#
# /content/drive/MyDrive/Image/Dataset2/burned-area/q (109).png
#
# /content/drive/MyDrive/Image/Dataset2/burned-area/u (88).png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/a (87).png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/a (82).png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/9 (253).png
#
# /content/drive/MyDrive/Image/Dataset2/green-area/scene01281.png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/16 (2).png
#
# /content/drive/MyDrive/Image/Dataset2/fire-smoke/14 (6).png
#
# /content/drive/MyDrive/Image/Dataset2/burned-area/o (145).png
#
# /content/drive/MyDrive/Image/Dataset2/green-area/11 (13).png
#
# /content/drive/MyDrive/Image/Dataset2/fog-area/5 (4).png
#
# /content/drive/MyDrive/Image/Dataset2/burned-area/y (75).png
#
# /content/drive/MyDrive/Image/Dataset2/burned-area/w (1).png
#
# /content/drive/MyDrive/Image/Dataset2/fog-area/11 (9).png

# %%
file = open("/content/drive/MyDrive/Image/testLabel.txt", "r")
# content = file.read()
    # testLabel.append(line)
Lines = file.readlines()
testLabel = []
for line in Lines:
    count += 1
    print(line)

    testLabel.append(line)
    # print("Line{}: {}".format(count, line.strip()))
 
# print("\nContent in file1.txt:\n", content)
file.close()
# Out:
# burned-area
#
# fog-area
#
# green-area
#
# green-area
#
# fire-smoke
#
# fog-area
#
# fog-area
#
# fire-smoke
#
# burned-area
#
# burned-area
#
# burned-area
#
# fire-smoke
#
# fire-smoke
#
# fog-area
#
# green-area
#
# fire-smoke
#
# burned-area
#
# fire-smoke
#
# fire-smoke
#
# fire-smoke
#
# green-area
#
# burned-area
#
# fire-smoke
#
# fire-smoke
#
# fire-smoke
#
# fire-smoke
#
# burned-area
#
# burned-area
#
# fire-smoke
#
# burned-area
#
# fire-smoke
#
# fire-smoke
#
# fire-smoke
#
# fire-smoke
#
# fire-smoke
#
# fire-smoke
#
# fog-area
#
# fire-smoke
#
# fog-area
#
# burned-area
#
# green-area
#
# burned-area
#
# fire-smoke
#
# fire-smoke
#
# burned-area
#
# fog-area
#
# fire-smoke
#
# fog-area
#
# fog-area
#
# green-area
#
# green-area
#
# green-area
#
# green-area
#
# burned-area
#
# burned-area
#
# fire-smoke
#
# burned-area
#
# green-area
#
# fog-area
#
# burned-area
#
# burned-area
#
# green-area
#
# burned-area
#
# fog-area
#
# burned-area
#
# burned-area
#
# green-area
#
# burned-area
#
# burned-area
#
# burned-area
#
# fire-smoke
#
# burned-area
#
# burned-area
#
# fog-area
#
# fog-area
#
# green-area
#
# fog-area
#
# green-area
#
# green-area
#
# burned-area
#
# fire-smoke
#
# fire-smoke
#
# fog-area
#
# green-area
#
# green-area
#
# green-area
#
# fire-smoke
#
# fire-smoke
#
# fire-smoke
#
# green-area
#
# burned-area
#
# green-area
#
# fog-area
#
# green-area
#
# fog-area
#
# fire-smoke
#
# fire-smoke
#
# fog-area
#
# fire-smoke
#
# burned-area
#
# fog-area
#
# burned-area
#
# green-area
#
# fog-area
#
# fire-smoke
#
# burned-area
#
# fire-smoke
#
# fire-smoke
#
# fog-area
#
# fire-smoke
#
# burned-area
#
# burned-area
#
# fire-smoke
#
# burned-area
#
# fog-area
#
# fire-smoke
#
# burned-area
#
# fire-smoke
#
# green-area
#
# fire-smoke
#
# burned-area
#
# fog-area
#
# fog-area
#
# fire-smoke
#
# green-area
#
# burned-area
#
# green-area
#
# green-area
#
# fog-area
#
# burned-area
#
# burned-area
#
# burned-area
#
# fire-smoke
#
# fire-smoke
#
# green-area
#
# fire-smoke
#
# burned-area
#
# fog-area
#
# fog-area
#
# fire-smoke
#
# green-area
#
# green-area
#
# burned-area
#
# fog-area
#
# fire-smoke
#
# fire-smoke
#
# green-area
#
# fire-smoke
#
# fire-smoke
#
# fire-smoke
#
# burned-area
#
# green-area
#
# fire-smoke
#
# burned-area
#
# fire-smoke
#
# fog-area
#
# green-area
#
# fire-smoke
#
# fog-area
#
# burned-area
#
# burned-area
#
# fire-smoke
#
# burned-area
#
# burned-area
#
# fire-smoke
#
# fire-smoke
#
# green-area
#
# burned-area
#
# burned-area
#
# fog-area
#
# burned-area
#
# fog-area
#
# fire-smoke
#
# burned-area
#
# fire-smoke
#
# burned-area
#
# green-area
#
# green-area
#
# fire-smoke
#
# burned-area
#
# fire-smoke
#
# green-area
#
# fire-smoke
#
# fire-smoke
#
# burned-area
#
# fog-area
#
# fire-smoke
#
# green-area
#
# fire-smoke
#
# burned-area
#
# fire-smoke
#
# green-area
#
# burned-area
#
# burned-area
#
# fire-smoke
#
# green-area
#
# green-area
#
# green-area
#
# burned-area
#
# fire-smoke
#
# fire-smoke
#
# burned-area
#
# fire-smoke
#
# burned-area
#
# green-area
#
# green-area
#
# fire-smoke
#
# fog-area
#
# fog-area
#
# green-area
#
# fire-smoke
#
# green-area
#
# fire-smoke
#
# fire-smoke
#
# burned-area
#
# fog-area
#
# fire-smoke
#
# green-area
#
# green-area
#
# burned-area
#
# burned-area
#
# burned-area
#
# fog-area
#
# burned-area
#
# green-area
#
# fire-smoke
#
# burned-area
#
# green-area
#
# green-area
#
# fog-area
#
# burned-area
#
# burned-area
#
# fire-smoke
#
# fog-area
#
# fire-smoke
#
# burned-area
#
# green-area
#
# fire-smoke
#
# green-area
#
# fire-smoke
#
# fire-smoke
#
# fog-area
#
# fog-area
#
# burned-area
#
# burned-area
#
# fire-smoke
#
# burned-area
#
# burned-area
#
# burned-area
#
# burned-area
#
# burned-area
#
# fire-smoke
#
# fire-smoke
#
# green-area
#
# fog-area
#
# burned-area
#
# fire-smoke
#
# burned-area
#
# green-area
#
# fire-smoke
#
# fire-smoke
#
# burned-area
#
# green-area
#
# fog-area
#
# burned-area
#
# fire-smoke
#
# burned-area
#
# fog-area
#
# burned-area
#
# fog-area
#
# burned-area
#
# burned-area
#
# burned-area
#
# fire-smoke
#
# green-area
#
# burned-area
#
# fire-smoke
#
# burned-area
#
# burned-area
#
# fire-smoke
#
# fog-area
#
# green-area
#
# burned-area
#
# burned-area
#
# fog-area
#
# burned-area
#
# burned-area
#
# burned-area
#
# fire-smoke
#
# fire-smoke
#
# burned-area
#
# burned-area
#
# fire-smoke
#
# fog-area
#
# burned-area
#
# fog-area
#
# burned-area
#
# fire-smoke
#
# burned-area
#
# fire-smoke
#
# fog-area
#
# burned-area
#
# green-area
#
# fog-area
#
# fire-smoke
#
# fire-smoke
#
# fire-smoke
#
# fog-area
#
# green-area
#
# fire-smoke
#
# fire-smoke
#
# green-area
#
# fire-smoke
#
# fire-smoke
#
# burned-area
#
# green-area
#
# burned-area
#
# fog-area
#
# fire-smoke
#
# fog-area
#
# burned-area
#
# fire-smoke
#
# fog-area
#
# green-area
#
# fire-smoke
#
# fog-area
#
# green-area
#
# burned-area
#
# fire-smoke
#
# green-area
#
# fire-smoke
#
# burned-area
#
# fog-area
#
# burned-area
#
# fire-smoke
#
# fire-smoke
#
# fog-area
#
# fog-area
#
# burned-area
#
# burned-area
#
# burned-area
#
# green-area
#
# green-area
#
# green-area
#
# burned-area
#
# burned-area
#
# burned-area
#
# fire-smoke
#
# burned-area
#
# burned-area
#
# burned-area
#
# fire-smoke
#
# burned-area
#
# fire-smoke
#
# fire-smoke
#
# green-area
#
# fog-area
#
# fire-smoke
#
# burned-area
#
# burned-area
#
# burned-area
#
# green-area
#
# burned-area
#
# burned-area
#
# fire-smoke
#
# burned-area
#
# fire-smoke
#
# fog-area
#
# burned-area
#
# fog-area
#
# fog-area
#
# burned-area
#
# green-area
#
# burned-area
#
# fire-smoke
#
# burned-area
#
# green-area
#
# fire-smoke
#
# fire-smoke
#
# burned-area
#
# fog-area
#
# fire-smoke
#
# green-area
#
# fog-area
#
# burned-area
#
# fog-area
#
# fog-area
#
# fog-area
#
# green-area
#
# burned-area
#
# fog-area
#
# fire-smoke
#
# fog-area
#
# fire-smoke
#
# green-area
#
# fog-area
#
# green-area
#
# fog-area
#
# fire-smoke
#
# green-area
#
# burned-area
#
# burned-area
#
# fire-smoke
#
# fire-smoke
#
# green-area
#
# fog-area
#
# fog-area
#
# green-area
#
# burned-area
#
# burned-area
#
# burned-area
#
# burned-area
#
# fire-smoke
#
# fog-area
#
# fog-area
#
# green-area
#
# green-area
#
# fire-smoke
#
# green-area
#
# fog-area
#
# green-area
#
# burned-area
#
# fire-smoke
#
# green-area
#
# burned-area
#
# fire-smoke
#
# fire-smoke
#
# green-area
#
# burned-area
#
# green-area
#
# fog-area
#
# fog-area
#
# fire-smoke
#
# fog-area
#
# green-area
#
# burned-area
#
# green-area
#
# green-area
#
# fire-smoke
#
# fire-smoke
#
# fire-smoke
#
# fog-area
#
# fire-smoke
#
# fog-area
#
# fire-smoke
#
# fire-smoke
#
# fire-smoke
#
# fire-smoke
#
# green-area
#
# fire-smoke
#
# green-area
#
# burned-area
#
# burned-area
#
# green-area
#
# burned-area
#
# green-area
#
# fog-area
#
# burned-area
#
# fire-smoke
#
# fire-smoke
#
# burned-area
#
# burned-area
#
# fog-area
#
# fog-area
#
# fire-smoke
#
# fog-area
#
# green-area
#
# green-area
#
# fog-area
#
# fog-area
#
# green-area
#
# fog-area
#
# fire-smoke
#
# fire-smoke
#
# burned-area
#
# green-area
#
# fire-smoke
#
# fog-area
#
# green-area
#
# fire-smoke
#
# fog-area
#
# fog-area
#
# fire-smoke
#
# fire-smoke
#
# burned-area
#
# fog-area
#
# fog-area
#
# fire-smoke
#
# fire-smoke
#
# burned-area
#
# burned-area
#
# burned-area
#
# burned-area
#
# green-area
#
# fire-smoke
#
# fire-smoke
#
# green-area
#
# burned-area
#
# fog-area
#
# burned-area
#
# burned-area
#
# burned-area
#
# fog-area
#
# burned-area
#
# green-area
#
# fire-smoke
#
# fire-smoke
#
# green-area
#
# fire-smoke
#
# green-area
#
# burned-area
#
# fog-area
#
# fire-smoke
#
# burned-area
#
# fire-smoke
#
# burned-area
#
# burned-area
#
# green-area
#
# burned-area
#
# green-area
#
# fog-area
#
# green-area
#
# fire-smoke
#
# fire-smoke
#
# fog-area
#
# fire-smoke
#
# green-area
#
# fog-area
#
# fire-smoke
#
# fire-smoke
#
# fog-area
#
# green-area
#
# fog-area
#
# fire-smoke
#
# fire-smoke
#
# green-area
#
# fog-area
#
# fire-smoke
#
# fire-smoke
#
# green-area
#
# fire-smoke
#
# fire-smoke
#
# fog-area
#
# fire-smoke
#
# fire-smoke
#
# green-area
#
# fire-smoke
#
# fire-smoke
#
# fire-smoke
#
# green-area
#
# fire-smoke
#
# burned-area
#
# fire-smoke
#
# green-area
#
# fog-area
#
# burned-area
#
# fog-area
#
# fire-smoke
#
# burned-area
#
# burned-area
#
# green-area
#
# green-area
#
# fog-area
#
# fog-area
#
# burned-area
#
# green-area
#
# fire-smoke
#
# green-area
#
# burned-area
#
# fog-area
#
# fire-smoke
#
# green-area
#
# green-area
#
# burned-area
#
# fire-smoke
#
# fire-smoke
#
# fire-smoke
#
# fog-area
#
# fog-area
#
# fire-smoke
#
# green-area
#
# fog-area
#
# fire-smoke
#
# burned-area
#
# fog-area
#
# fire-smoke
#
# fire-smoke
#
# green-area
#
# green-area
#
# fire-smoke
#
# fire-smoke
#
# fog-area
#
# fog-area
#
# burned-area
#
# fire-smoke
#
# fire-smoke
#
# fire-smoke
#
# fog-area
#
# fog-area
#
# burned-area
#
# green-area
#
# fire-smoke
#
# green-area
#
# green-area
#
# fire-smoke
#
# fire-smoke
#
# burned-area
#
# fog-area
#
# burned-area
#
# fire-smoke
#
# fire-smoke
#
# fog-area
#
# fire-smoke
#
# fire-smoke
#
# fire-smoke
#
# fire-smoke
#
# green-area
#
# green-area
#
# fog-area
#
# burned-area
#
# green-area
#
# burned-area
#
# fire-smoke
#
# green-area
#
# fire-smoke
#
# fire-smoke
#
# green-area
#
# fire-smoke
#
# fog-area
#
# burned-area
#
# fog-area
#
# green-area
#
# fog-area
#
# burned-area
#
# burned-area
#
# fire-smoke
#
# fire-smoke
#
# green-area
#
# burned-area
#
# fog-area
#
# fire-smoke
#
# green-area
#
# fire-smoke
#
# burned-area
#
# burned-area
#
# burned-area
#
# fog-area
#
# fire-smoke
#
# burned-area
#
# fire-smoke
#
# green-area
#
# fire-smoke
#
# burned-area
#
# green-area
#
# green-area
#
# green-area
#
# fire-smoke
#
# burned-area
#
# fog-area
#
# green-area
#
# fog-area
#
# fog-area
#
# green-area
#
# fog-area
#
# fog-area
#
# fog-area
#
# fire-smoke
#
# fire-smoke
#
# green-area
#
# fire-smoke
#
# burned-area
#
# burned-area
#
# fog-area
#
# green-area
#
# burned-area
#
# fire-smoke
#
# fog-area
#
# burned-area
#
# green-area
#
# fire-smoke
#
# green-area
#
# burned-area
#
# fog-area
#
# fog-area
#
# fire-smoke
#
# fog-area
#
# fog-area
#
# green-area
#
# fog-area
#
# fog-area
#
# green-area
#
# fire-smoke
#
# green-area
#
# burned-area
#
# green-area
#
# green-area
#
# green-area
#
# burned-area
#
# fog-area
#
# fog-area
#
# fire-smoke
#
# fire-smoke
#
# fire-smoke
#
# burned-area
#
# burned-area
#
# fog-area
#
# fog-area
#
# burned-area
#
# burned-area
#
# fire-smoke
#
# green-area
#
# green-area
#
# fog-area
#
# burned-area
#
# burned-area
#
# fog-area
#
# fog-area
#
# fog-area
#
# fire-smoke
#
# fire-smoke
#
# fire-smoke
#
# fire-smoke
#
# fog-area
#
# burned-area
#
# green-area
#
# fog-area
#
# fire-smoke
#
# fog-area
#
# green-area
#
# fog-area
#
# burned-area
#
# fire-smoke
#
# green-area
#
# fog-area
#
# burned-area
#
# fire-smoke
#
# fog-area
#
# fog-area
#
# burned-area
#
# fire-smoke
#
# burned-area
#
# burned-area
#
# burned-area
#
# fire-smoke
#
# fire-smoke
#
# green-area
#
# fog-area
#
# burned-area
#
# green-area
#
# burned-area
#
# fog-area
#
# green-area
#
# green-area
#
# green-area
#
# fire-smoke
#
# fire-smoke
#
# fog-area
#
# fire-smoke
#
# burned-area
#
# green-area
#
# burned-area
#
# burned-area
#
# fire-smoke
#
# fire-smoke
#
# fire-smoke
#
# burned-area
#
# burned-area
#
# green-area
#
# burned-area
#
# fire-smoke
#
# fog-area
#
# fire-smoke
#
# green-area
#
# fire-smoke
#
# green-area
#
# fire-smoke
#
# burned-area
#
# fire-smoke
#
# burned-area
#
# burned-area
#
# burned-area
#
# burned-area
#
# green-area
#
# green-area
#
# burned-area
#
# fire-smoke
#
# burned-area
#
# fire-smoke
#
# green-area
#
# burned-area
#
# burned-area
#
# fog-area
#
# green-area
#
# burned-area
#
# fog-area
#
# fire-smoke
#
# fire-smoke
#
# fog-area
#
# fog-area
#
# burned-area
#
# fog-area
#
# burned-area
#
# fire-smoke
#
# burned-area
#
# fog-area
#
# burned-area
#
# burned-area
#
# fog-area
#
# fog-area
#
# burned-area
#
# fire-smoke
#
# burned-area
#
# green-area
#
# green-area
#
# burned-area
#
# fire-smoke
#
# fog-area
#
# fire-smoke
#
# green-area
#
# fire-smoke
#
# fire-smoke
#
# burned-area
#
# green-area
#
# fire-smoke
#
# green-area
#
# fire-smoke
#
# green-area
#
# burned-area
#
# fire-smoke
#
# fog-area
#
# burned-area
#
# green-area
#
# fog-area
#
# green-area
#
# burned-area
#
# green-area
#
# burned-area
#
# fire-smoke
#
# fire-smoke
#
# fire-smoke
#
# burned-area
#
# fire-smoke
#
# fire-smoke
#
# green-area
#
# fire-smoke
#
# fire-smoke
#
# fog-area
#
# burned-area
#
# fire-smoke
#
# fog-area
#
# burned-area
#
# fog-area
#
# green-area
#
# fog-area
#
# fog-area
#
# fog-area
#
# green-area
#
# fire-smoke
#
# fog-area
#
# fog-area
#
# green-area
#
# fire-smoke
#
# burned-area
#
# green-area
#
# fog-area
#
# fire-smoke
#
# fire-smoke
#
# fire-smoke
#
# green-area
#
# green-area
#
# fire-smoke
#
# fire-smoke
#
# fire-smoke
#
# fire-smoke
#
# fire-smoke
#
# fire-smoke
#
# fire-smoke
#
# burned-area
#
# fire-smoke
#
# fire-smoke
#
# green-area
#
# fire-smoke
#
# fire-smoke
#
# fire-smoke
#
# green-area
#
# burned-area
#
# fog-area
#
# green-area
#
# fog-area
#
# burned-area
#
# burned-area
#
# burned-area
#
# fire-smoke
#
# fire-smoke
#
# burned-area
#
# burned-area
#
# fire-smoke
#
# fire-smoke
#
# fog-area
#
# burned-area
#
# fire-smoke
#
# burned-area
#
# fire-smoke
#
# fog-area
#
# burned-area
#
# fire-smoke
#
# burned-area
#
# burned-area
#
# fog-area
#
# green-area
#
# fire-smoke
#
# green-area
#
# burned-area
#
# fire-smoke
#
# fog-area
#
# fire-smoke
#
# fire-smoke
#
# burned-area
#
# green-area
#
# burned-area
#
# burned-area
#
# burned-area
#
# fog-area
#
# fire-smoke
#
# burned-area
#
# fire-smoke
#
# fire-smoke
#
# fog-area
#
# fog-area
#
# fire-smoke
#
# fog-area
#
# burned-area
#
# burned-area
#
# fire-smoke
#
# fire-smoke
#
# fog-area
#
# fog-area
#
# fire-smoke
#
# fire-smoke
#
# fog-area
#
# burned-area
#
# fog-area
#
# fire-smoke
#
# fog-area
#
# burned-area
#
# green-area
#
# fire-smoke
#
# burned-area
#
# fire-smoke
#
# burned-area
#
# fire-smoke
#
# fire-smoke
#
# fire-smoke
#
# fog-area
#
# green-area
#
# burned-area
#
# fog-area
#
# fire-smoke
#
# burned-area
#
# fog-area
#
# fog-area
#
# fire-smoke
#
# burned-area
#
# fire-smoke
#
# green-area
#
# burned-area
#
# burned-area
#
# green-area
#
# fire-smoke
#
# burned-area
#
# burned-area
#
# burned-area
#
# burned-area
#
# fog-area
#
# green-area
#
# green-area
#
# fog-area
#
# fog-area
#
# green-area
#
# fog-area
#
# burned-area
#
# green-area
#
# burned-area
#
# fog-area
#
# fire-smoke
#
# green-area
#
# green-area
#
# burned-area
#
# green-area
#
# burned-area
#
# fog-area
#
# fog-area
#
# burned-area
#
# burned-area
#
# burned-area
#
# green-area
#
# green-area
#
# fog-area
#
# fire-smoke
#
# fog-area
#
# burned-area
#
# fog-area
#
# fog-area
#
# fire-smoke
#
# burned-area
#
# fire-smoke
#
# burned-area
#
# fog-area
#
# fog-area
#
# burned-area
#
# green-area
#
# fire-smoke
#
# green-area
#
# burned-area
#
# fog-area
#
# fog-area
#
# fire-smoke
#
# fog-area
#
# fire-smoke
#
# fog-area
#
# fire-smoke
#
# burned-area
#
# fire-smoke
#
# green-area
#
# fog-area
#
# green-area
#
# burned-area
#
# burned-area
#
# fog-area
#
# green-area
#
# green-area
#
# fog-area
#
# burned-area
#
# fog-area
#
# fog-area
#
# fog-area
#
# green-area
#
# fog-area
#
# burned-area
#
# green-area
#
# green-area
#
# fire-smoke
#
# fire-smoke
#
# fire-smoke
#
# burned-area
#
# fog-area
#
# fire-smoke
#
# burned-area
#
# green-area
#
# fire-smoke
#
# fog-area
#
# burned-area
#
# fog-area
#
# green-area
#
# green-area
#
# fire-smoke
#
# burned-area
#
# fog-area
#
# fire-smoke
#
# fire-smoke
#
# green-area
#
# fire-smoke
#
# fog-area
#
# fire-smoke
#
# fog-area
#
# fire-smoke
#
# fire-smoke
#
# burned-area
#
# burned-area
#
# fog-area
#
# burned-area
#
# fog-area
#
# burned-area
#
# fire-smoke
#
# green-area
#
# fire-smoke
#
# fire-smoke
#
# burned-area
#
# fire-smoke
#
# burned-area
#
# burned-area
#
# fire-smoke
#
# burned-area
#
# burned-area
#
# burned-area
#
# green-area
#
# fire-smoke
#
# fire-smoke
#
# green-area
#
# fire-smoke
#
# fog-area
#
# fire-smoke
#
# fire-smoke
#
# fire-smoke
#
# burned-area
#
# fog-area
#
# burned-area
#
# fog-area
#
# green-area
#
# fog-area
#
# burned-area
#
# fire-smoke
#
# fog-area
#
# fire-smoke
#
# green-area
#
# fire-smoke
#
# burned-area
#
# green-area
#
# burned-area
#
# burned-area
#
# fire-smoke
#
# fog-area
#
# burned-area
#
# fire-smoke
#
# burned-area
#
# green-area
#
# burned-area
#
# fire-smoke
#
# burned-area
#
# fire-smoke
#
# green-area
#
# green-area
#
# fire-smoke
#
# fire-smoke
#
# fog-area
#
# fire-smoke
#
# green-area
#
# green-area
#
# fire-smoke
#
# green-area
#
# green-area
#
# fire-smoke
#
# burned-area
#
# burned-area
#
# fire-smoke
#
# fire-smoke
#
# fire-smoke
#
# fire-smoke
#
# fire-smoke
#
# green-area
#
# green-area
#
# fog-area
#
# fire-smoke
#
# burned-area
#
# green-area
#
# fire-smoke
#
# burned-area
#
# fog-area
#
# burned-area
#
# fog-area
#
# fog-area
#
# burned-area
#
# fire-smoke
#
# fog-area
#
# fire-smoke
#
# burned-area
#
# fire-smoke
#
# fog-area
#
# fire-smoke
#
# fire-smoke
#
# green-area
#
# fog-area
#
# burned-area
#
# fire-smoke
#
# green-area
#
# burned-area
#
# green-area
#
# green-area
#
# green-area
#
# burned-area
#
# fog-area
#
# burned-area
#
# burned-area
#
# burned-area
#
# fire-smoke
#
# burned-area
#
# fog-area
#
# fire-smoke
#
# burned-area
#
# green-area
#
# fire-smoke
#
# green-area
#
# fire-smoke
#
# fire-smoke
#
# green-area
#
# fire-smoke
#
# green-area
#
# green-area
#
# fire-smoke
#
# burned-area
#
# fog-area
#
# green-area
#
# fire-smoke
#
# fog-area
#
# fire-smoke
#
# burned-area
#
# burned-area
#
# fire-smoke
#
# fog-area
#
# fog-area
#
# green-area
#
# burned-area
#
# green-area
#
# green-area
#
# green-area
#
# burned-area
#
# burned-area
#
# green-area
#
# green-area
#
# fog-area
#
# green-area
#
# fire-smoke
#
# burned-area
#
# fog-area
#
# green-area
#
# green-area
#
# burned-area
#
# fire-smoke
#
# fire-smoke
#
# burned-area
#
# fire-smoke
#
# fire-smoke
#
# fog-area
#
# fire-smoke
#
# fire-smoke
#
# green-area
#
# burned-area
#
# fog-area
#
# burned-area
#
# fire-smoke
#
# fire-smoke
#
# green-area
#
# burned-area
#
# fog-area
#
# burned-area
#
# fire-smoke
#
# fire-smoke
#
# fire-smoke
#
# fire-smoke
#
# burned-area
#
# fire-smoke
#
# fire-smoke
#
# burned-area
#
# fog-area
#
# burned-area
#
# green-area
#
# fire-smoke
#
# fog-area
#
# fog-area
#
# fire-smoke
#
# fire-smoke
#
# fog-area
#
# fire-smoke
#
# green-area
#
# fog-area
#
# burned-area
#
# fire-smoke
#
# burned-area
#
# burned-area
#
# burned-area
#
# fire-smoke
#
# fire-smoke
#
# green-area
#
# green-area
#
# green-area
#
# green-area
#
# burned-area
#
# green-area
#
# fire-smoke
#
# green-area
#
# fire-smoke
#
# burned-area
#
# fire-smoke
#
# green-area
#
# green-area
#
# green-area
#
# fog-area
#
# fire-smoke
#
# burned-area
#
# fire-smoke
#
# green-area
#
# fire-smoke
#
# fire-smoke
#
# green-area
#
# burned-area
#
# fog-area
#
# fire-smoke
#
# fog-area
#
# fire-smoke
#
# fog-area
#
# green-area
#
# fog-area
#
# burned-area
#
# green-area
#
# fog-area
#
# fire-smoke
#
# fog-area
#
# green-area
#
# fire-smoke
#
# fire-smoke
#
# green-area
#
# fire-smoke
#
# burned-area
#
# green-area
#
# green-area
#
# fire-smoke
#
# fog-area
#
# burned-area
#
# fog-area
#
# fog-area
#
# burned-area
#
# fog-area
#
# fire-smoke
#
# burned-area
#
# fire-smoke
#
# fire-smoke
#
# green-area
#
# burned-area
#
# burned-area
#
# burned-area
#
# fire-smoke
#
# burned-area
#
# burned-area
#
# fire-smoke
#
# fire-smoke
#
# fire-smoke
#
# fire-smoke
#
# fog-area
#
# fire-smoke
#
# fire-smoke
#
# fire-smoke
#
# fire-smoke
#
# fire-smoke
#
# fire-smoke
#
# burned-area
#
# fire-smoke
#
# green-area
#
# burned-area
#
# fire-smoke
#
# green-area
#
# fire-smoke
#
# burned-area
#
# fire-smoke
#
# burned-area
#
# fire-smoke
#
# fog-area
#
# burned-area
#
# burned-area
#
# green-area
#
# burned-area
#
# burned-area
#
# fog-area
#
# burned-area
#
# green-area
#
# burned-area
#
# fire-smoke
#
# fog-area
#
# fire-smoke
#
# fire-smoke
#
# green-area
#
# fog-area
#
# green-area
#
# fire-smoke
#
# burned-area
#
# fire-smoke
#
# fire-smoke
#
# fog-area
#
# fog-area
#
# burned-area
#
# fire-smoke
#
# fire-smoke
#
# burned-area
#
# burned-area
#
# green-area
#
# burned-area
#
# fire-smoke
#
# burned-area
#
# fog-area
#
# fire-smoke
#
# fire-smoke
#
# fire-smoke
#
# fog-area
#
# fire-smoke
#
# burned-area
#
# fire-smoke
#
# fog-area
#
# fog-area
#
# burned-area
#
# burned-area
#
# fog-area
#
# fire-smoke
#
# fog-area
#
# fog-area
#
# burned-area
#
# fog-area
#
# fire-smoke
#
# burned-area
#
# fire-smoke
#
# burned-area
#
# fire-smoke
#
# fog-area
#
# green-area
#
# fire-smoke
#
# green-area
#
# burned-area
#
# fire-smoke
#
# fog-area
#
# fire-smoke
#
# fog-area
#
# fire-smoke
#
# burned-area
#
# fog-area
#
# fire-smoke
#
# fog-area
#
# fire-smoke
#
# fire-smoke
#
# fog-area
#
# burned-area
#
# fog-area
#
# burned-area
#
# burned-area
#
# burned-area
#
# fire-smoke
#
# fog-area
#
# fire-smoke
#
# fire-smoke
#
# green-area
#
# green-area
#
# green-area
#
# fire-smoke
#
# fire-smoke
#
# fog-area
#
# fire-smoke
#
# green-area
#
# fire-smoke
#
# fire-smoke
#
# burned-area
#
# fog-area
#
# burned-area
#
# fog-area
#
# fire-smoke
#
# fog-area
#
# fire-smoke
#
# fog-area
#
# burned-area
#
# fire-smoke
#
# green-area
#
# fire-smoke
#
# fire-smoke
#
# fog-area
#
# burned-area
#
# green-area
#
# fire-smoke
#
# burned-area
#
# fire-smoke
#
# green-area
#
# green-area
#
# fire-smoke
#
# fire-smoke
#
# burned-area
#
# fog-area
#
# burned-area
#
# burned-area
#
# burned-area
#
# fire-smoke
#
# green-area
#
# fog-area
#
# green-area
#
# fire-smoke
#
# fire-smoke
#
# green-area
#
# fire-smoke
#
# burned-area
#
# fire-smoke
#
# fire-smoke
#
# fog-area
#
# green-area
#
# fire-smoke
#
# burned-area
#
# fog-area
#
# green-area
#
# burned-area
#
# fire-smoke
#
# burned-area
#
# green-area
#
# green-area
#
# fog-area
#
# fire-smoke
#
# fog-area
#
# burned-area
#
# fog-area
#
# green-area
#
# fire-smoke
#
# fire-smoke
#
# fire-smoke
#
# fire-smoke
#
# green-area
#
# fog-area
#
# burned-area
#
# green-area
#
# fire-smoke
#
# green-area
#
# fire-smoke
#
# burned-area
#
# fog-area
#
# fire-smoke
#
# fog-area
#
# green-area
#
# burned-area
#
# fire-smoke
#
# fire-smoke
#
# fire-smoke
#
# green-area
#
# fog-area
#
# fog-area
#
# fire-smoke
#
# fog-area
#
# fog-area
#
# fog-area
#
# fog-area
#
# green-area
#
# fire-smoke
#
# fog-area
#
# fire-smoke
#
# green-area
#
# fire-smoke
#
# green-area
#
# burned-area
#
# burned-area
#
# fog-area
#
# burned-area
#
# fire-smoke
#
# green-area
#
# burned-area
#
# fire-smoke
#
# green-area
#
# burned-area
#
# fog-area
#
# green-area
#
# fog-area
#
# fog-area
#
# fire-smoke
#
# fog-area
#
# burned-area
#
# fire-smoke
#
# fog-area
#
# burned-area
#
# burned-area
#
# fire-smoke
#
# green-area
#
# fire-smoke
#
# burned-area
#
# fog-area
#
# fog-area
#
# burned-area
#
# burned-area
#
# fire-smoke
#
# fog-area
#
# fog-area
#
# fire-smoke
#
# burned-area
#
# burned-area
#
# green-area
#
# fire-smoke
#
# fog-area
#
# fog-area
#
# fire-smoke
#
# fire-smoke
#
# fire-smoke
#
# burned-area
#
# fog-area
#
# fog-area
#
# green-area
#
# fire-smoke
#
# fog-area
#
# burned-area
#
# green-area
#
# green-area
#
# burned-area
#
# fire-smoke
#
# fog-area
#
# fire-smoke
#
# green-area
#
# burned-area
#
# burned-area
#
# fire-smoke
#
# fog-area
#
# green-area
#
# fire-smoke
#
# green-area
#
# fog-area
#
# burned-area
#
# green-area
#
# fire-smoke
#
# green-area
#
# fire-smoke
#
# fog-area
#
# burned-area
#
# green-area
#
# burned-area
#
# burned-area
#
# green-area
#
# green-area
#
# burned-area
#
# burned-area
#
# burned-area
#
# fog-area
#
# fire-smoke
#
# burned-area
#
# fog-area
#
# fog-area
#
# burned-area
#
# burned-area
#
# burned-area
#
# fog-area
#
# burned-area
#
# green-area
#
# fog-area
#
# fire-smoke
#
# fire-smoke
#
# fire-smoke
#
# fire-smoke
#
# fire-smoke
#
# green-area
#
# burned-area
#
# fog-area
#
# green-area
#
# fire-smoke
#
# fog-area
#
# fire-smoke
#
# fire-smoke
#
# fire-smoke
#
# fog-area
#
# fog-area
#
# fog-area
#
# green-area
#
# fire-smoke
#
# fog-area
#
# fire-smoke
#
# green-area
#
# fire-smoke
#
# fog-area
#
# fire-smoke
#
# burned-area
#
# fire-smoke
#
# burned-area
#
# fog-area
#
# fire-smoke
#
# green-area
#
# fire-smoke
#
# burned-area
#
# fire-smoke
#
# fog-area
#
# fire-smoke
#
# green-area
#
# fog-area
#
# fire-smoke
#
# fire-smoke
#
# fire-smoke
#
# green-area
#
# green-area
#
# green-area
#
# burned-area
#
# burned-area
#
# fire-smoke
#
# fire-smoke
#
# fire-smoke
#
# green-area
#
# fire-smoke
#
# fire-smoke
#
# fire-smoke
#
# fog-area
#
# burned-area
#
# fog-area
#
# fire-smoke
#
# fog-area
#
# burned-area
#
# burned-area
#
# fire-smoke
#
# fog-area
#
# burned-area
#
# green-area
#
# fog-area
#
# burned-area
#
# fire-smoke
#
# burned-area
#
# fog-area
#
# green-area
#
# fire-smoke
#
# burned-area
#
# green-area
#
# fog-area
#
# green-area
#
# fire-smoke
#
# fog-area
#
# fog-area
#
# fog-area
#
# burned-area
#
# burned-area
#
# burned-area
#
# green-area
#
# burned-area
#
# burned-area
#
# burned-area
#
# fire-smoke
#
# fire-smoke
#
# fog-area
#
# green-area
#
# burned-area
#
# green-area
#
# fog-area
#
# burned-area
#
# burned-area
#
# fog-area
#
# fog-area
#
# fog-area
#
# burned-area
#
# fire-smoke
#
# fog-area
#
# fire-smoke
#
# fog-area
#
# burned-area
#
# fire-smoke
#
# fire-smoke
#
# fire-smoke
#
# burned-area
#
# green-area
#
# fog-area
#
# fog-area
#
# fog-area
#
# fire-smoke
#
# fog-area
#
# burned-area
#
# green-area
#
# burned-area
#
# burned-area
#
# green-area
#
# fog-area
#
# green-area
#
# fog-area
#
# fire-smoke
#
# green-area
#
# burned-area
#
# fire-smoke
#
# fog-area
#
# fire-smoke
#
# fog-area
#
# green-area
#
# green-area
#
# fire-smoke
#
# burned-area
#
# green-area
#
# fog-area
#
# fire-smoke
#
# fog-area
#
# burned-area
#
# green-area
#
# fire-smoke
#
# fog-area
#
# burned-area
#
# burned-area
#
# fog-area
#
# fire-smoke
#
# green-area
#
# fire-smoke
#
# fire-smoke
#
# fog-area
#
# fire-smoke
#
# green-area
#
# fire-smoke
#
# green-area
#
# fire-smoke
#
# fire-smoke
#
# green-area
#
# burned-area
#
# fog-area
#
# burned-area
#
# fire-smoke
#
# fire-smoke
#
# fog-area
#
# burned-area
#
# fire-smoke
#
# fire-smoke
#
# fog-area
#
# fire-smoke
#
# fog-area
#
# burned-area
#
# green-area
#
# fog-area
#
# fire-smoke
#
# fire-smoke
#
# burned-area
#
# fog-area
#
# fire-smoke
#
# fire-smoke
#
# fire-smoke
#
# burned-area
#
# fog-area
#
# fire-smoke
#
# burned-area
#
# fire-smoke
#
# burned-area
#
# green-area
#
# fire-smoke
#
# fog-area
#
# burned-area
#
# fog-area
#
# fire-smoke
#
# green-area
#
# green-area
#
# green-area
#
# burned-area
#
# fog-area
#
# fire-smoke
#
# green-area
#
# fire-smoke
#
# burned-area
#
# fire-smoke
#
# burned-area
#
# burned-area
#
# burned-area
#
# green-area
#
# fire-smoke
#
# fire-smoke
#
# fire-smoke
#
# fire-smoke
#
# green-area
#
# fire-smoke
#
# fog-area
#
# burned-area
#
# burned-area
#
# green-area
#
# green-area
#
# fire-smoke
#
# fire-smoke
#
# fog-area
#
# burned-area
#
# green-area
#
# fire-smoke
#
# fog-area
#
# burned-area
#
# burned-area
#
# fire-smoke
#
# burned-area
#
# fire-smoke
#
# burned-area
#
# burned-area
#
# green-area
#
# burned-area
#
# fog-area
#
# fire-smoke
#
# green-area
#
# burned-area
#
# green-area
#
# burned-area
#
# burned-area
#
# green-area
#
# green-area
#
# fog-area
#
# fire-smoke
#
# green-area
#
# fog-area
#
# burned-area
#
# fire-smoke
#
# burned-area
#
# fire-smoke
#
# green-area
#
# green-area
#
# fog-area
#
# burned-area
#
# fire-smoke
#
# green-area
#
# fire-smoke
#
# fire-smoke
#
# fire-smoke
#
# burned-area
#
# burned-area
#
# fire-smoke
#
# burned-area
#
# green-area
#
# fog-area
#
# green-area
#
# burned-area
#
# fire-smoke
#
# fog-area
#
# burned-area
#
# green-area
#
# fire-smoke
#
# fire-smoke
#
# burned-area
#
# burned-area
#
# fire-smoke
#
# burned-area
#
# fog-area
#
# green-area
#
# fire-smoke
#
# fog-area
#
# fire-smoke
#
# burned-area
#
# green-area
#
# burned-area
#
# green-area
#
# green-area
#
# fire-smoke
#
# burned-area
#
# fog-area
#
# green-area
#
# burned-area
#
# fog-area
#
# burned-area
#
# fire-smoke
#
# fog-area
#
# fire-smoke
#
# fire-smoke
#
# green-area
#
# green-area
#
# green-area
#
# burned-area
#
# fire-smoke
#
# burned-area
#
# burned-area
#
# fire-smoke
#
# green-area
#
# burned-area
#
# fog-area
#
# burned-area
#
# fog-area
#
# fire-smoke
#
# green-area
#
# green-area
#
# fire-smoke
#
# burned-area
#
# green-area
#
# burned-area
#
# fog-area
#
# burned-area
#
# fire-smoke
#
# fog-area
#
# fire-smoke
#
# fog-area
#
# burned-area
#
# fire-smoke
#
# green-area
#
# fog-area
#
# fire-smoke
#
# burned-area
#
# green-area
#
# burned-area
#
# fog-area
#
# fire-smoke
#
# fire-smoke
#
# fog-area
#
# burned-area
#
# fire-smoke
#
# fog-area
#
# green-area
#
# fire-smoke
#
# burned-area
#
# green-area
#
# burned-area
#
# burned-area
#
# fire-smoke
#
# burned-area
#
# fog-area
#
# green-area
#
# green-area
#
# fog-area
#
# fire-smoke
#
# burned-area
#
# fire-smoke
#
# green-area
#
# fog-area
#
# burned-area
#
# fire-smoke
#
# green-area
#
# fog-area
#
# fire-smoke
#
# fire-smoke
#
# green-area
#
# fire-smoke
#
# fire-smoke
#
# fog-area
#
# fire-smoke
#
# fire-smoke
#
# fire-smoke
#
# fire-smoke
#
# burned-area
#
# burned-area
#
# fire-smoke
#
# burned-area
#
# fog-area
#
# fire-smoke
#
# fire-smoke
#
# fire-smoke
#
# green-area
#
# fog-area
#
# green-area
#
# green-area
#
# burned-area
#
# fire-smoke
#
# green-area
#
# fog-area
#
# fire-smoke
#
# burned-area
#
# green-area
#
# fire-smoke
#
# burned-area
#
# fire-smoke
#
# fire-smoke
#
# fog-area
#
# burned-area
#
# fire-smoke
#
# green-area
#
# green-area
#
# burned-area
#
# fire-smoke
#
# fire-smoke
#
# fire-smoke
#
# fire-smoke
#
# fire-smoke
#
# green-area
#
# fire-smoke
#
# green-area
#
# fire-smoke
#
# fire-smoke
#
# fire-smoke
#
# burned-area
#
# fire-smoke
#
# green-area
#
# burned-area
#
# fog-area
#
# fire-smoke
#
# green-area
#
# green-area
#
# green-area
#
# fire-smoke
#
# fire-smoke
#
# burned-area
#
# green-area
#
# burned-area
#
# green-area
#
# fire-smoke
#
# fire-smoke
#
# fire-smoke
#
# fog-area
#
# fire-smoke
#
# fire-smoke
#
# burned-area
#
# burned-area
#
# green-area
#
# fire-smoke
#
# burned-area
#
# fog-area
#
# fog-area
#
# green-area
#
# burned-area
#
# green-area
#
# fire-smoke
#
# burned-area
#
# fog-area
#
# green-area
#
# green-area
#
# green-area
#
# fog-area
#
# fire-smoke
#
# green-area
#
# fire-smoke
#
# burned-area
#
# fire-smoke
#
# burned-area
#
# fog-area
#
# fire-smoke
#
# fire-smoke
#
# green-area
#
# fog-area
#
# fire-smoke
#
# burned-area
#
# burned-area
#
# fog-area
#
# fog-area
#
# fire-smoke
#
# fire-smoke
#
# fire-smoke
#
# fog-area
#
# green-area
#
# green-area
#
# fog-area
#
# green-area
#
# green-area
#
# burned-area
#
# burned-area
#
# fog-area
#
# fire-smoke
#
# green-area
#
# green-area
#
# fire-smoke
#
# burned-area
#
# fire-smoke
#
# green-area
#
# fire-smoke
#
# fire-smoke
#
# green-area
#
# green-area
#
# fog-area
#
# green-area
#
# fog-area
#
# fire-smoke
#
# burned-area
#
# fog-area
#
# fire-smoke
#
# fog-area
#
# green-area
#
# fire-smoke
#
# fog-area
#
# fire-smoke
#
# burned-area
#
# fog-area
#
# fire-smoke
#
# burned-area
#
# burned-area
#
# burned-area
#
# fire-smoke
#
# green-area
#
# burned-area
#
# burned-area
#
# fog-area
#
# fire-smoke
#
# fog-area
#
# burned-area
#
# fire-smoke
#
# green-area
#
# green-area
#
# burned-area
#
# fire-smoke
#
# green-area
#
# burned-area
#
# burned-area
#
# burned-area
#
# fire-smoke
#
# fire-smoke
#
# green-area
#
# fire-smoke
#
# fog-area
#
# green-area
#
# fog-area
#
# burned-area
#
# fog-area
#
# fire-smoke
#
# fire-smoke
#
# green-area
#
# fire-smoke
#
# burned-area
#
# burned-area
#
# fire-smoke
#
# fire-smoke
#
# fire-smoke
#
# fog-area
#
# burned-area
#
# fog-area
#
# burned-area
#
# fire-smoke
#
# burned-area
#
# fire-smoke
#
# fog-area
#
# fire-smoke
#
# fire-smoke
#
# green-area
#
# fog-area
#
# fog-area
#
# fire-smoke
#
# fire-smoke
#
# burned-area
#
# fog-area
#
# fog-area
#
# green-area
#
# burned-area
#
# burned-area
#
# fog-area
#
# fire-smoke
#
# fire-smoke
#
# burned-area
#
# burned-area
#
# fire-smoke
#
# fire-smoke
#
# fire-smoke
#
# fog-area
#
# fog-area
#
# fog-area
#
# burned-area
#
# burned-area
#
# burned-area
#
# green-area
#
# green-area
#
# burned-area
#
# burned-area
#
# burned-area
#
# fire-smoke
#
# fire-smoke
#
# burned-area
#
# fog-area
#
# burned-area
#
# green-area
#
# green-area
#
# burned-area
#
# green-area
#
# green-area
#
# fog-area
#
# fire-smoke
#
# green-area
#
# burned-area
#
# fog-area
#
# green-area
#
# fog-area
#
# green-area
#
# green-area
#
# burned-area
#
# green-area
#
# fire-smoke
#
# fire-smoke
#
# fire-smoke
#
# fire-smoke
#
# burned-area
#
# fire-smoke
#
# fog-area
#
# burned-area
#
# burned-area
#
# burned-area
#
# fire-smoke
#
# green-area
#
# fire-smoke
#
# fog-area
#
# fog-area
#
# fire-smoke
#
# fire-smoke
#
# fire-smoke
#
# burned-area
#
# fire-smoke
#
# fog-area
#
# burned-area
#
# fire-smoke
#
# burned-area
#
# fog-area
#
# green-area
#
# fire-smoke
#
# fog-area
#
# fire-smoke
#
# fire-smoke
#
# burned-area
#
# green-area
#
# fog-area
#
# fire-smoke
#
# green-area
#
# green-area
#
# fire-smoke
#
# fire-smoke
#
# fire-smoke
#
# burned-area
#
# fire-smoke
#
# green-area
#
# fire-smoke
#
# fire-smoke
#
# fire-smoke
#
# burned-area
#
# fire-smoke
#
# burned-area
#
# fire-smoke
#
# burned-area
#
# fog-area
#
# green-area
#
# burned-area
#
# fire-smoke
#
# burned-area
#
# burned-area
#
# burned-area
#
# fire-smoke
#
# fog-area
#
# green-area
#
# burned-area
#
# burned-area
#
# fire-smoke
#
# green-area
#
# fog-area
#
# fire-smoke
#
# fire-smoke
#
# fire-smoke
#
# fog-area
#
# green-area
#
# fog-area
#
# green-area
#
# fire-smoke
#
# burned-area
#
# burned-area
#
# green-area
#
# fog-area
#
# burned-area
#
# fog-area
#
# fire-smoke
#
# fire-smoke
#
# fog-area
#
# fire-smoke
#
# fire-smoke
#
# green-area
#
# fire-smoke
#
# fog-area
#
# fire-smoke
#
# green-area
#
# fog-area
#
# fire-smoke
#
# fire-smoke
#
# burned-area
#
# green-area
#
# burned-area
#
# burned-area
#
# fire-smoke
#
# green-area
#
# burned-area
#
# fire-smoke
#
# fog-area
#
# fire-smoke
#
# fire-smoke
#
# fire-smoke
#
# burned-area
#
# fire-smoke
#
# fog-area
#
# burned-area
#
# fire-smoke
#
# fire-smoke
#
# fog-area
#
# burned-area
#
# burned-area
#
# fire-smoke
#
# fire-smoke
#
# fire-smoke
#
# green-area
#
# fire-smoke
#
# fire-smoke
#
# burned-area
#
# green-area
#
# fog-area
#
# burned-area
#
# burned-area
#
# fog-area

# %%
len(testData), len(testLabel), type(testData)
# Out:
# (2342, 2342, list)

# %%
# tf.device('/gpu:0')
# dir = "/content/drive/MyDrive/Image/Dataset2/"
# test_dir = dir
# label = []
# list_of_folders = os.listdir(test_dir)
# frame_paths = []

# for folder in list_of_folders:
#     print("folder: ", folder)
#     list_of_files = os.listdir(test_dir + "/" + folder)
#     pattern = "*.png"
#     counter = 0
#     for entry in list_of_files:
#         if fnmatch.fnmatch(entry, pattern):
#             file_path = test_dir + folder + "/" + entry
#             frame_paths.append(file_path)
#             label.append(folder)

# %%
# train_val_data, test_data, train_val_labels, test_labels = train_test_split(frame_paths, label, test_size=0.5, random_state=42)

# %%
# # save numpy array as csv file
# from numpy import asarray
# from numpy import savetxt

# %%
tempData = np.array(testData)
templabel = np.array(testLabel)

# %%
templabel = np.array(testLabel)

# %%
templabel
# Out:
# array(['burned-area\n', 'fog-area\n', 'green-area\n', ...,
#        'burned-area\n', 'burned-area\n', 'fog-area\n'], dtype='<U12')

# %%
# len(tempData)

# %%
# file = open("/content/drive/MyDrive/Image/testData.txt", "w+")
 
# # Saving the array in a text file
# for item in tempData:

#   content = str(item)
#   file.write(content)
#   content = str("\n")
#   file.write(content)
# file.close()
 
# file = open("/content/drive/MyDrive/Image/testLabel.txt", "w+")
 
# # Saving the array in a text file
# for item in templabel:

#   content = str(item)
#   file.write(content)
#   content = str("\n")
#   file.write(content)
# file.close()

# # # Displaying the contents of the text file
# # file = open("/content/drive/MyDrive/Image/file3.txt", "r")
# # # content = file.read()
# # # print(type(content))
# # Lines = file.readlines()
  
# # count = 0
# # # Strips the newline character
# # for line in Lines:
# #     count += 1
# #     print(line)
# #     # print("Line{}: {}".format(count, line.strip()))
 
# # # print("\nContent in file1.txt:\n", content)
# # file.close()

# %%
# file = open("/content/drive/MyDrive/Image/file1.txt", "w+")
 
# # Saving the array in a text file
# content = str(tempData)
# file.write(content)
# file.close()
 
# # Displaying the contents of the text file
# file = open("/content/drive/MyDrive/Image/file1.txt", "r")
# content = file.read()

 
# print("\nContent in file1.txt:\n", content)
# file.close()

# %%
# savetxt('/content/drive/MyDrive/Image/data.txt', test_data, delimiter=',')

# %%
# from sklearn.preprocessing import LabelEncoder

# le = LabelEncoder()

# numerical_labels = le.fit_transform(train_val_labels)

# for label, num in zip(le.classes_, le.transform(le.classes_)):
#     print(f"{label} : {num}")
# train_val_y = np.array(numerical_labels)

# numerical_labels = le.fit_transform(test_labels)

# for label, num in zip(le.classes_, le.transform(le.classes_)):
#     print(f"{label} : {num}")
# test_y = np.array(numerical_labels)

# %% [markdown]
# #Preprocessing

# %%
# tf.device('/gpu:0')
# train_data2 = []
# for i in train_val_data:
#     file_path = i
#     image = tf.io.read_file(file_path)
#     image = tf.image.decode_png(image, channels=3)
#     image = tf.cast(image, tf.float32) * (1. / 255)
#     image = tf.image.resize(image, [224, 224])
#     image = tf.reshape(image, (224, 224, 3))
#     train_data2.append(image)

# %%
# test_dir = "/content/drive/MyDrive/Image/Dataset2/burned-area"
# list_of_folders = os.listdir(test_dir)

# %%
# list_of_folders

# %%
tf.device('/gpu:0')
test_data2 = []
for i in tempData:
    file_path = str(i)
    # print("i :", file_path)
    p = ""
    for j in range(len(file_path)-1):
      # print("^")
      p=p+file_path[j]
      # print(file_path[j])
      # print("&")
    # print("$")
    # print(type(str(i)))
    image = tf.io.read_file(p)
    image = tf.image.decode_png(image, channels=3)
    image = tf.cast(image, tf.float32) * (1. / 255)
    image = tf.image.resize(image, [224, 224])
    image = tf.reshape(image, (224, 224, 3))
    test_data2.append(image)
# Out:
# i : /content/drive/MyDrive/Image/Dataset2/burned-area/u (47).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fog-area/4 (28).png
#
# i : /content/drive/MyDrive/Image/Dataset2/green-area/8 (68).png
#
# i : /content/drive/MyDrive/Image/Dataset2/green-area/8 (8).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fire-smoke/a (40).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fog-area/scene00801.png
#
# i : /content/drive/MyDrive/Image/Dataset2/fog-area/7 (2).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fire-smoke/9 (138).png
#
# i : /content/drive/MyDrive/Image/Dataset2/burned-area/o (234).png
#
# i : /content/drive/MyDrive/Image/Dataset2/burned-area/q (149).png
#
# i : /content/drive/MyDrive/Image/Dataset2/burned-area/o (185).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fire-smoke/9 (314).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fire-smoke/g (67).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fog-area/scene03881.png
#
# i : /content/drive/MyDrive/Image/Dataset2/green-area/6 (45).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fire-smoke/9 (124).png
#
# i : /content/drive/MyDrive/Image/Dataset2/burned-area/o (342).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fire-smoke/p (125).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fire-smoke/14 (59).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fire-smoke/11 (94).png
#
# i : /content/drive/MyDrive/Image/Dataset2/green-area/10 (33).png
#
# i : /content/drive/MyDrive/Image/Dataset2/burned-area/q (78).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fire-smoke/9 (195).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fire-smoke/g (40).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fire-smoke/g (54).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fire-smoke/14 (55).png
#
# i : /content/drive/MyDrive/Image/Dataset2/burned-area/u (161).png
#
# i : /content/drive/MyDrive/Image/Dataset2/burned-area/u (51).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fire-smoke/p (4).png
#
# i : /content/drive/MyDrive/Image/Dataset2/burned-area/y (41).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fire-smoke/8 (64).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fire-smoke/9 (55).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fire-smoke/g (6).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fire-smoke/9 (282).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fire-smoke/8 (71).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fire-smoke/11 (15).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fog-area/5 (25).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fire-smoke/s (19).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fog-area/9 (10).png
#
# i : /content/drive/MyDrive/Image/Dataset2/burned-area/q (139).png
#
# i : /content/drive/MyDrive/Image/Dataset2/green-area/8 (21).png
#
# i : /content/drive/MyDrive/Image/Dataset2/burned-area/q (5).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fire-smoke/9 (82).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fire-smoke/8 (115).png
#
# i : /content/drive/MyDrive/Image/Dataset2/burned-area/q (90).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fog-area/scene02721.png
#
# i : /content/drive/MyDrive/Image/Dataset2/fire-smoke/g (25).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fog-area/5 (14).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fog-area/10 (63).png
#
# i : /content/drive/MyDrive/Image/Dataset2/green-area/scene07001.png
#
# i : /content/drive/MyDrive/Image/Dataset2/green-area/scene07801.png
#
# i : /content/drive/MyDrive/Image/Dataset2/green-area/12 (56).png
#
# i : /content/drive/MyDrive/Image/Dataset2/green-area/4 (46).png
#
# i : /content/drive/MyDrive/Image/Dataset2/burned-area/u (140).png
#
# i : /content/drive/MyDrive/Image/Dataset2/burned-area/q (61).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fire-smoke/11 (170).png
#
# i : /content/drive/MyDrive/Image/Dataset2/burned-area/y (27).png
#
# i : /content/drive/MyDrive/Image/Dataset2/green-area/8 (15).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fog-area/scene06281.png
#
# i : /content/drive/MyDrive/Image/Dataset2/burned-area/o (96).png
#
# i : /content/drive/MyDrive/Image/Dataset2/burned-area/o (143).png
#
# i : /content/drive/MyDrive/Image/Dataset2/green-area/scene00801.png
#
# i : /content/drive/MyDrive/Image/Dataset2/burned-area/q (76).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fog-area/3 (70).png
#
# i : /content/drive/MyDrive/Image/Dataset2/burned-area/o (315).png
#
# i : /content/drive/MyDrive/Image/Dataset2/burned-area/o (4).png
#
# i : /content/drive/MyDrive/Image/Dataset2/green-area/scene02201.png
#
# i : /content/drive/MyDrive/Image/Dataset2/burned-area/t (54).png
#
# i : /content/drive/MyDrive/Image/Dataset2/burned-area/y (25).png
#
# i : /content/drive/MyDrive/Image/Dataset2/burned-area/e (32).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fire-smoke/p (50).png
#
# i : /content/drive/MyDrive/Image/Dataset2/burned-area/o (69).png
#
# i : /content/drive/MyDrive/Image/Dataset2/burned-area/e (10).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fog-area/scene01721.png
#
# i : /content/drive/MyDrive/Image/Dataset2/fog-area/10 (34).png
#
# i : /content/drive/MyDrive/Image/Dataset2/green-area/7 (32).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fog-area/8 (71).png
#
# i : /content/drive/MyDrive/Image/Dataset2/green-area/scene03401.png
#
# i : /content/drive/MyDrive/Image/Dataset2/green-area/10 (57).png
#
# i : /content/drive/MyDrive/Image/Dataset2/burned-area/u (22).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fire-smoke/15 (28).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fire-smoke/9 (111).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fog-area/4 (21).png
#
# i : /content/drive/MyDrive/Image/Dataset2/green-area/scene02841.png
#
# i : /content/drive/MyDrive/Image/Dataset2/green-area/5 (90).png
#
# i : /content/drive/MyDrive/Image/Dataset2/green-area/scene06201.png
#
# i : /content/drive/MyDrive/Image/Dataset2/fire-smoke/9 (25).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fire-smoke/a (80).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fire-smoke/8 (37).png
#
# i : /content/drive/MyDrive/Image/Dataset2/green-area/12 (44).png
#
# i : /content/drive/MyDrive/Image/Dataset2/burned-area/y (68).png
#
# i : /content/drive/MyDrive/Image/Dataset2/green-area/5 (28).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fog-area/3 (60).png
#
# i : /content/drive/MyDrive/Image/Dataset2/green-area/scene03281.png
#
# i : /content/drive/MyDrive/Image/Dataset2/fog-area/2 (11).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fire-smoke/g (1).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fire-smoke/scene03281.png
#
# i : /content/drive/MyDrive/Image/Dataset2/fog-area/9 (37).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fire-smoke/11 (149).png
#
# i : /content/drive/MyDrive/Image/Dataset2/burned-area/q (185).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fog-area/4 (18).png
#
# i : /content/drive/MyDrive/Image/Dataset2/burned-area/o (35).png
#
# i : /content/drive/MyDrive/Image/Dataset2/green-area/scene08681.png
#
# i : /content/drive/MyDrive/Image/Dataset2/fog-area/scene03641.png
#
# i : /content/drive/MyDrive/Image/Dataset2/fire-smoke/scene08881.png
#
# i : /content/drive/MyDrive/Image/Dataset2/burned-area/scene03761.png
#
# i : /content/drive/MyDrive/Image/Dataset2/fire-smoke/g (69).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fire-smoke/11 (122).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fog-area/3 (175).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fire-smoke/8 (47).png
#
# i : /content/drive/MyDrive/Image/Dataset2/burned-area/o (48).png
#
# i : /content/drive/MyDrive/Image/Dataset2/burned-area/q (142).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fire-smoke/f (39).png
#
# i : /content/drive/MyDrive/Image/Dataset2/burned-area/q (107).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fog-area/2 (45).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fire-smoke/9 (66).png
#
# i : /content/drive/MyDrive/Image/Dataset2/burned-area/y (4).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fire-smoke/11 (37).png
#
# i : /content/drive/MyDrive/Image/Dataset2/green-area/scene03241.png
#
# i : /content/drive/MyDrive/Image/Dataset2/fire-smoke/9 (257).png
#
# i : /content/drive/MyDrive/Image/Dataset2/burned-area/r (25).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fog-area/scene01321.png
#
# i : /content/drive/MyDrive/Image/Dataset2/fog-area/4 (107).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fire-smoke/9 (262).png
#
# i : /content/drive/MyDrive/Image/Dataset2/green-area/4 (15).png
#
# i : /content/drive/MyDrive/Image/Dataset2/burned-area/o (142).png
#
# i : /content/drive/MyDrive/Image/Dataset2/green-area/12 (58).png
#
# i : /content/drive/MyDrive/Image/Dataset2/green-area/11 (31).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fog-area/8 (27).png
#
# i : /content/drive/MyDrive/Image/Dataset2/burned-area/r (28).png
#
# i : /content/drive/MyDrive/Image/Dataset2/burned-area/o (154).png
#
# i : /content/drive/MyDrive/Image/Dataset2/burned-area/e (12).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fire-smoke/p (12).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fire-smoke/10 (87).png
#
# i : /content/drive/MyDrive/Image/Dataset2/green-area/7 (29).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fire-smoke/g (3).png
#
# i : /content/drive/MyDrive/Image/Dataset2/burned-area/o (207).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fog-area/4 (77).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fog-area/9 (16).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fire-smoke/11 (174).png
#
# i : /content/drive/MyDrive/Image/Dataset2/green-area/12 (55).png
#
# i : /content/drive/MyDrive/Image/Dataset2/green-area/3 (44).png
#
# i : /content/drive/MyDrive/Image/Dataset2/burned-area/o (134).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fog-area/4 (85).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fire-smoke/9 (95).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fire-smoke/10 (78).png
#
# i : /content/drive/MyDrive/Image/Dataset2/green-area/8 (25).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fire-smoke/15 (78).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fire-smoke/9 (211).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fire-smoke/10 (102).png
#
# i : /content/drive/MyDrive/Image/Dataset2/burned-area/q (128).png
#
# i : /content/drive/MyDrive/Image/Dataset2/green-area/4 (47).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fire-smoke/10 (89).png
#
# i : /content/drive/MyDrive/Image/Dataset2/burned-area/o (181).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fire-smoke/12 (28).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fog-area/8 (36).png
#
# i : /content/drive/MyDrive/Image/Dataset2/green-area/scene04161.png
#
# i : /content/drive/MyDrive/Image/Dataset2/fire-smoke/10 (18).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fog-area/3 (9).png
#
# i : /content/drive/MyDrive/Image/Dataset2/burned-area/w (22).png
#
# i : /content/drive/MyDrive/Image/Dataset2/burned-area/o (112).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fire-smoke/15 (58).png
#
# i : /content/drive/MyDrive/Image/Dataset2/burned-area/t (64).png
#
# i : /content/drive/MyDrive/Image/Dataset2/burned-area/q (124).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fire-smoke/12 (55).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fire-smoke/11 (181).png
#
# i : /content/drive/MyDrive/Image/Dataset2/green-area/11 (19).png
#
# i : /content/drive/MyDrive/Image/Dataset2/burned-area/o (257).png
#
# i : /content/drive/MyDrive/Image/Dataset2/burned-area/o (285).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fog-area/3 (174).png
#
# i : /content/drive/MyDrive/Image/Dataset2/burned-area/y (8).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fog-area/10 (106).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fire-smoke/g (50).png
#
# i : /content/drive/MyDrive/Image/Dataset2/burned-area/scene00961.png
#
# i : /content/drive/MyDrive/Image/Dataset2/fire-smoke/12 (92).png
#
# i : /content/drive/MyDrive/Image/Dataset2/burned-area/q (216).png
#
# i : /content/drive/MyDrive/Image/Dataset2/green-area/8 (57).png
#
# i : /content/drive/MyDrive/Image/Dataset2/green-area/5 (81).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fire-smoke/10 (2).png
#
# i : /content/drive/MyDrive/Image/Dataset2/burned-area/q (32).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fire-smoke/scene00481.png
#
# i : /content/drive/MyDrive/Image/Dataset2/green-area/scene03801.png
#
# i : /content/drive/MyDrive/Image/Dataset2/fire-smoke/11 (97).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fire-smoke/14 (66).png
#
# i : /content/drive/MyDrive/Image/Dataset2/burned-area/q (95).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fog-area/4 (9).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fire-smoke/scene01161.png
#
# i : /content/drive/MyDrive/Image/Dataset2/green-area/9 (14).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fire-smoke/p (115).png
#
# i : /content/drive/MyDrive/Image/Dataset2/burned-area/w (35).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fire-smoke/9 (216).png
#
# i : /content/drive/MyDrive/Image/Dataset2/green-area/7 (12).png
#
# i : /content/drive/MyDrive/Image/Dataset2/burned-area/y (69).png
#
# i : /content/drive/MyDrive/Image/Dataset2/burned-area/o (237).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fire-smoke/15 (22).png
#
# i : /content/drive/MyDrive/Image/Dataset2/green-area/8 (82).png
#
# i : /content/drive/MyDrive/Image/Dataset2/green-area/3 (33).png
#
# i : /content/drive/MyDrive/Image/Dataset2/green-area/scene00201.png
#
# i : /content/drive/MyDrive/Image/Dataset2/burned-area/scene02081.png
#
# i : /content/drive/MyDrive/Image/Dataset2/fire-smoke/10 (54).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fire-smoke/p (72).png
#
# i : /content/drive/MyDrive/Image/Dataset2/burned-area/o (165).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fire-smoke/9 (26).png
#
# i : /content/drive/MyDrive/Image/Dataset2/burned-area/q (65).png
#
# i : /content/drive/MyDrive/Image/Dataset2/green-area/11 (12).png
#
# i : /content/drive/MyDrive/Image/Dataset2/green-area/scene05201.png
#
# i : /content/drive/MyDrive/Image/Dataset2/fire-smoke/a (66).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fog-area/3 (194).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fog-area/9 (36).png
#
# i : /content/drive/MyDrive/Image/Dataset2/green-area/4 (26).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fire-smoke/11 (101).png
#
# i : /content/drive/MyDrive/Image/Dataset2/green-area/5 (64).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fire-smoke/11 (58).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fire-smoke/11 (153).png
#
# i : /content/drive/MyDrive/Image/Dataset2/burned-area/u (156).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fog-area/scene03921.png
#
# i : /content/drive/MyDrive/Image/Dataset2/fire-smoke/15 (7).png
#
# i : /content/drive/MyDrive/Image/Dataset2/green-area/scene00441.png
#
# i : /content/drive/MyDrive/Image/Dataset2/green-area/12 (23).png
#
# i : /content/drive/MyDrive/Image/Dataset2/burned-area/u (113).png
#
# i : /content/drive/MyDrive/Image/Dataset2/burned-area/scene01641.png
#
# i : /content/drive/MyDrive/Image/Dataset2/burned-area/t (89).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fog-area/6 (17).png
#
# i : /content/drive/MyDrive/Image/Dataset2/burned-area/u (165).png
#
# i : /content/drive/MyDrive/Image/Dataset2/green-area/4 (55).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fire-smoke/11 (2).png
#
# i : /content/drive/MyDrive/Image/Dataset2/burned-area/w (13).png
#
# i : /content/drive/MyDrive/Image/Dataset2/green-area/4 (41).png
#
# i : /content/drive/MyDrive/Image/Dataset2/green-area/scene01121.png
#
# i : /content/drive/MyDrive/Image/Dataset2/fog-area/8 (47).png
#
# i : /content/drive/MyDrive/Image/Dataset2/burned-area/o (267).png
#
# i : /content/drive/MyDrive/Image/Dataset2/burned-area/y (70).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fire-smoke/s (14).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fog-area/8 (72).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fire-smoke/8 (129).png
#
# i : /content/drive/MyDrive/Image/Dataset2/burned-area/q (145).png
#
# i : /content/drive/MyDrive/Image/Dataset2/green-area/10 (1).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fire-smoke/scene01721.png
#
# i : /content/drive/MyDrive/Image/Dataset2/green-area/11 (9).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fire-smoke/11 (63).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fire-smoke/10 (31).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fog-area/3 (191).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fog-area/2 (76).png
#
# i : /content/drive/MyDrive/Image/Dataset2/burned-area/o (83).png
#
# i : /content/drive/MyDrive/Image/Dataset2/burned-area/t (63).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fire-smoke/9 (261).png
#
# i : /content/drive/MyDrive/Image/Dataset2/burned-area/scene01881.png
#
# i : /content/drive/MyDrive/Image/Dataset2/burned-area/u (80).png
#
# i : /content/drive/MyDrive/Image/Dataset2/burned-area/q (60).png
#
# i : /content/drive/MyDrive/Image/Dataset2/burned-area/q (83).png
#
# i : /content/drive/MyDrive/Image/Dataset2/burned-area/u (50).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fire-smoke/10 (112).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fire-smoke/8 (135).png
#
# i : /content/drive/MyDrive/Image/Dataset2/green-area/10 (45).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fog-area/scene06561.png
#
# i : /content/drive/MyDrive/Image/Dataset2/burned-area/q (195).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fire-smoke/14 (21).png
#
# i : /content/drive/MyDrive/Image/Dataset2/burned-area/o (347).png
#
# i : /content/drive/MyDrive/Image/Dataset2/green-area/7 (44).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fire-smoke/9 (125).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fire-smoke/p (14).png
#
# i : /content/drive/MyDrive/Image/Dataset2/burned-area/o (11).png
#
# i : /content/drive/MyDrive/Image/Dataset2/green-area/5 (91).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fog-area/2 (16).png
#
# i : /content/drive/MyDrive/Image/Dataset2/burned-area/o (71).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fire-smoke/8 (54).png
#
# i : /content/drive/MyDrive/Image/Dataset2/burned-area/t (19).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fog-area/scene07361.png
#
# i : /content/drive/MyDrive/Image/Dataset2/burned-area/u (109).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fog-area/scene00201.png
#
# i : /content/drive/MyDrive/Image/Dataset2/burned-area/scene02201.png
#
# i : /content/drive/MyDrive/Image/Dataset2/burned-area/q (177).png
#
# i : /content/drive/MyDrive/Image/Dataset2/burned-area/t (7).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fire-smoke/a (35).png
#
# i : /content/drive/MyDrive/Image/Dataset2/green-area/5 (8).png
#
# i : /content/drive/MyDrive/Image/Dataset2/burned-area/i (1).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fire-smoke/11 (157).png
#
# i : /content/drive/MyDrive/Image/Dataset2/burned-area/q (186).png
#
# i : /content/drive/MyDrive/Image/Dataset2/burned-area/u (163).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fire-smoke/9 (115).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fog-area/scene09321.png
#
# i : /content/drive/MyDrive/Image/Dataset2/green-area/scene07761.png
#
# i : /content/drive/MyDrive/Image/Dataset2/burned-area/o (190).png
#
# i : /content/drive/MyDrive/Image/Dataset2/burned-area/q (18).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fog-area/scene00601.png
#
# i : /content/drive/MyDrive/Image/Dataset2/burned-area/o (172).png
#
# i : /content/drive/MyDrive/Image/Dataset2/burned-area/q (19).png
#
# i : /content/drive/MyDrive/Image/Dataset2/burned-area/t
png
#
# i : /content/drive/MyDrive/Image/Dataset2/burned-area/y (75).png
#
# i : /content/drive/MyDrive/Image/Dataset2/burned-area/w (1).png
#
# i : /content/drive/MyDrive/Image/Dataset2/fog-area/11 (9).png

# %%
tf.device('/gpu:0')
test_label2 = []
for i in templabel:
    file_path = str(i)
    print("i :", file_path)
    p = ""
    for j in range(len(file_path)-1):
      # print("^")
      p=p+file_path[j]
      # print(file_path[j])
      # print("&")
    # print("$")
    # print(type(str(i)))

    test_label2.append(p)
# Out:
# i : burned-area
#
# i : fog-area
#
# i : green-area
#
# i : green-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : fog-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : burned-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fog-area
#
# i : green-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : green-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : burned-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fog-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : burned-area
#
# i : green-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : burned-area
#
# i : fog-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : fog-area
#
# i : green-area
#
# i : green-area
#
# i : green-area
#
# i : green-area
#
# i : burned-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : green-area
#
# i : fog-area
#
# i : burned-area
#
# i : burned-area
#
# i : green-area
#
# i : burned-area
#
# i : fog-area
#
# i : burned-area
#
# i : burned-area
#
# i : green-area
#
# i : burned-area
#
# i : burned-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : burned-area
#
# i : fog-area
#
# i : fog-area
#
# i : green-area
#
# i : fog-area
#
# i : green-area
#
# i : green-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fog-area
#
# i : green-area
#
# i : green-area
#
# i : green-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : green-area
#
# i : burned-area
#
# i : green-area
#
# i : fog-area
#
# i : green-area
#
# i : fog-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fog-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : fog-area
#
# i : burned-area
#
# i : green-area
#
# i : fog-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fog-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : fog-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : fire-smoke
#
# i : green-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : fog-area
#
# i : fog-area
#
# i : fire-smoke
#
# i : green-area
#
# i : burned-area
#
# i : green-area
#
# i : green-area
#
# i : fog-area
#
# i : burned-area
#
# i : burned-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : green-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : fog-area
#
# i : fog-area
#
# i : fire-smoke
#
# i : green-area
#
# i : green-area
#
# i : burned-area
#
# i : fog-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : green-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : burned-area
#
# i : green-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : green-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : burned-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : green-area
#
# i : burned-area
#
# i : burned-area
#
# i : fog-area
#
# i : burned-area
#
# i : fog-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : green-area
#
# i : green-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : fire-smoke
#
# i : green-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : burned-area
#
# i : fog-area
#
# i : fire-smoke
#
# i : green-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : fire-smoke
#
# i : green-area
#
# i : burned-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : green-area
#
# i : green-area
#
# i : green-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : burned-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : green-area
#
# i : green-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : fog-area
#
# i : green-area
#
# i : fire-smoke
#
# i : green-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : burned-area
#
# i : fog-area
#
# i : fire-smoke
#
# i : green-area
#
# i : green-area
#
# i : burned-area
#
# i : burned-area
#
# i : burned-area
#
# i : fog-area
#
# i : burned-area
#
# i : green-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : green-area
#
# i : green-area
#
# i : fog-area
#
# i : burned-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : green-area
#
# i : fire-smoke
#
# i : green-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fog-area
#
# i : fog-area
#
# i : burned-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : burned-area
#
# i : burned-area
#
# i : burned-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : green-area
#
# i : fog-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : green-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : burned-area
#
# i : green-area
#
# i : fog-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : fog-area
#
# i : burned-area
#
# i : fog-area
#
# i : burned-area
#
# i : burned-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : green-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : green-area
#
# i : burned-area
#
# i : burned-area
#
# i : fog-area
#
# i : burned-area
#
# i : burned-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : burned-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : burned-area
#
# i : fog-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : burned-area
#
# i : green-area
#
# i : fog-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fog-area
#
# i : green-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : green-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : burned-area
#
# i : green-area
#
# i : burned-area
#
# i : fog-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : green-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : green-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : green-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : fog-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fog-area
#
# i : fog-area
#
# i : burned-area
#
# i : burned-area
#
# i : burned-area
#
# i : green-area
#
# i : green-area
#
# i : green-area
#
# i : burned-area
#
# i : burned-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : burned-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : green-area
#
# i : fog-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : burned-area
#
# i : burned-area
#
# i : green-area
#
# i : burned-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : burned-area
#
# i : fog-area
#
# i : fog-area
#
# i : burned-area
#
# i : green-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : green-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : burned-area
#
# i : fog-area
#
# i : fire-smoke
#
# i : green-area
#
# i : fog-area
#
# i : burned-area
#
# i : fog-area
#
# i : fog-area
#
# i : fog-area
#
# i : green-area
#
# i : burned-area
#
# i : fog-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : fire-smoke
#
# i : green-area
#
# i : fog-area
#
# i : green-area
#
# i : fog-area
#
# i : fire-smoke
#
# i : green-area
#
# i : burned-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : green-area
#
# i : fog-area
#
# i : fog-area
#
# i : green-area
#
# i : burned-area
#
# i : burned-area
#
# i : burned-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : fog-area
#
# i : green-area
#
# i : green-area
#
# i : fire-smoke
#
# i : green-area
#
# i : fog-area
#
# i : green-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : green-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : green-area
#
# i : burned-area
#
# i : green-area
#
# i : fog-area
#
# i : fog-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : green-area
#
# i : burned-area
#
# i : green-area
#
# i : green-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fog-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : green-area
#
# i : fire-smoke
#
# i : green-area
#
# i : burned-area
#
# i : burned-area
#
# i : green-area
#
# i : burned-area
#
# i : green-area
#
# i : fog-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : burned-area
#
# i : burned-area
#
# i : fog-area
#
# i : fog-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : green-area
#
# i : green-area
#
# i : fog-area
#
# i : fog-area
#
# i : green-area
#
# i : fog-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : burned-area
#
# i : green-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : green-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : fog-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : burned-area
#
# i : fog-area
#
# i : fog-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : burned-area
#
# i : burned-area
#
# i : burned-area
#
# i : burned-area
#
# i : green-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : green-area
#
# i : burned-area
#
# i : fog-area
#
# i : burned-area
#
# i : burned-area
#
# i : burned-area
#
# i : fog-area
#
# i : burned-area
#
# i : green-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : green-area
#
# i : fire-smoke
#
# i : green-area
#
# i : burned-area
#
# i : fog-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : burned-area
#
# i : green-area
#
# i : burned-area
#
# i : green-area
#
# i : fog-area
#
# i : green-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fog-area
#
# i : fire-smoke
#
# i : green-area
#
# i : fog-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fog-area
#
# i : green-area
#
# i : fog-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : green-area
#
# i : fog-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : green-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fog-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : green-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : green-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : fire-smoke
#
# i : green-area
#
# i : fog-area
#
# i : burned-area
#
# i : fog-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : burned-area
#
# i : green-area
#
# i : green-area
#
# i : fog-area
#
# i : fog-area
#
# i : burned-area
#
# i : green-area
#
# i : fire-smoke
#
# i : green-area
#
# i : burned-area
#
# i : fog-area
#
# i : fire-smoke
#
# i : green-area
#
# i : green-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fog-area
#
# i : fog-area
#
# i : fire-smoke
#
# i : green-area
#
# i : fog-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : fog-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : green-area
#
# i : green-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fog-area
#
# i : fog-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fog-area
#
# i : fog-area
#
# i : burned-area
#
# i : green-area
#
# i : fire-smoke
#
# i : green-area
#
# i : green-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : burned-area
#
# i : fog-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fog-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : green-area
#
# i : green-area
#
# i : fog-area
#
# i : burned-area
#
# i : green-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : green-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : green-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : burned-area
#
# i : fog-area
#
# i : green-area
#
# i : fog-area
#
# i : burned-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : green-area
#
# i : burned-area
#
# i : fog-area
#
# i : fire-smoke
#
# i : green-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : burned-area
#
# i : burned-area
#
# i : fog-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : fire-smoke
#
# i : green-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : green-area
#
# i : green-area
#
# i : green-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : fog-area
#
# i : green-area
#
# i : fog-area
#
# i : fog-area
#
# i : green-area
#
# i : fog-area
#
# i : fog-area
#
# i : fog-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : green-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : burned-area
#
# i : fog-area
#
# i : green-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : burned-area
#
# i : green-area
#
# i : fire-smoke
#
# i : green-area
#
# i : burned-area
#
# i : fog-area
#
# i : fog-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : fog-area
#
# i : green-area
#
# i : fog-area
#
# i : fog-area
#
# i : green-area
#
# i : fire-smoke
#
# i : green-area
#
# i : burned-area
#
# i : green-area
#
# i : green-area
#
# i : green-area
#
# i : burned-area
#
# i : fog-area
#
# i : fog-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : burned-area
#
# i : burned-area
#
# i : fog-area
#
# i : fog-area
#
# i : burned-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : green-area
#
# i : green-area
#
# i : fog-area
#
# i : burned-area
#
# i : burned-area
#
# i : fog-area
#
# i : fog-area
#
# i : fog-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fog-area
#
# i : burned-area
#
# i : green-area
#
# i : fog-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : green-area
#
# i : fog-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : green-area
#
# i : fog-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : fog-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : burned-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : green-area
#
# i : fog-area
#
# i : burned-area
#
# i : green-area
#
# i : burned-area
#
# i : fog-area
#
# i : green-area
#
# i : green-area
#
# i : green-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fog-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : green-area
#
# i : burned-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : burned-area
#
# i : burned-area
#
# i : green-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : fire-smoke
#
# i : green-area
#
# i : fire-smoke
#
# i : green-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : burned-area
#
# i : burned-area
#
# i : burned-area
#
# i : green-area
#
# i : green-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : fire-smoke
#
# i : green-area
#
# i : burned-area
#
# i : burned-area
#
# i : fog-area
#
# i : green-area
#
# i : burned-area
#
# i : fog-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fog-area
#
# i : fog-area
#
# i : burned-area
#
# i : fog-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : fog-area
#
# i : burned-area
#
# i : burned-area
#
# i : fog-area
#
# i : fog-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : green-area
#
# i : green-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : fire-smoke
#
# i : green-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : burned-area
#
# i : green-area
#
# i : fire-smoke
#
# i : green-area
#
# i : fire-smoke
#
# i : green-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : burned-area
#
# i : green-area
#
# i : fog-area
#
# i : green-area
#
# i : burned-area
#
# i : green-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : burned-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : green-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fog-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : burned-area
#
# i : fog-area
#
# i : green-area
#
# i : fog-area
#
# i : fog-area
#
# i : fog-area
#
# i : green-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : fog-area
#
# i : green-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : green-area
#
# i : fog-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : green-area
#
# i : green-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : burned-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : green-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : green-area
#
# i : burned-area
#
# i : fog-area
#
# i : green-area
#
# i : fog-area
#
# i : burned-area
#
# i : burned-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : burned-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fog-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : burned-area
#
# i : fog-area
#
# i : green-area
#
# i : fire-smoke
#
# i : green-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : burned-area
#
# i : green-area
#
# i : burned-area
#
# i : burned-area
#
# i : burned-area
#
# i : fog-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fog-area
#
# i : fog-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : burned-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fog-area
#
# i : fog-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fog-area
#
# i : burned-area
#
# i : fog-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : burned-area
#
# i : green-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fog-area
#
# i : green-area
#
# i : burned-area
#
# i : fog-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : fog-area
#
# i : fog-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : fire-smoke
#
# i : green-area
#
# i : burned-area
#
# i : burned-area
#
# i : green-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : burned-area
#
# i : burned-area
#
# i : burned-area
#
# i : fog-area
#
# i : green-area
#
# i : green-area
#
# i : fog-area
#
# i : fog-area
#
# i : green-area
#
# i : fog-area
#
# i : burned-area
#
# i : green-area
#
# i : burned-area
#
# i : fog-area
#
# i : fire-smoke
#
# i : green-area
#
# i : green-area
#
# i : burned-area
#
# i : green-area
#
# i : burned-area
#
# i : fog-area
#
# i : fog-area
#
# i : burned-area
#
# i : burned-area
#
# i : burned-area
#
# i : green-area
#
# i : green-area
#
# i : fog-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : burned-area
#
# i : fog-area
#
# i : fog-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : fog-area
#
# i : fog-area
#
# i : burned-area
#
# i : green-area
#
# i : fire-smoke
#
# i : green-area
#
# i : burned-area
#
# i : fog-area
#
# i : fog-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : fire-smoke
#
# i : green-area
#
# i : fog-area
#
# i : green-area
#
# i : burned-area
#
# i : burned-area
#
# i : fog-area
#
# i : green-area
#
# i : green-area
#
# i : fog-area
#
# i : burned-area
#
# i : fog-area
#
# i : fog-area
#
# i : fog-area
#
# i : green-area
#
# i : fog-area
#
# i : burned-area
#
# i : green-area
#
# i : green-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : burned-area
#
# i : fog-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : green-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : burned-area
#
# i : fog-area
#
# i : green-area
#
# i : green-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : fog-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : green-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : burned-area
#
# i : burned-area
#
# i : fog-area
#
# i : burned-area
#
# i : fog-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : green-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : burned-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : burned-area
#
# i : burned-area
#
# i : green-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : green-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : burned-area
#
# i : fog-area
#
# i : burned-area
#
# i : fog-area
#
# i : green-area
#
# i : fog-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : fire-smoke
#
# i : green-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : green-area
#
# i : burned-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : green-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : fire-smoke
#
# i : green-area
#
# i : green-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fog-area
#
# i : fire-smoke
#
# i : green-area
#
# i : green-area
#
# i : fire-smoke
#
# i : green-area
#
# i : green-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : green-area
#
# i : green-area
#
# i : fog-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : green-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : fog-area
#
# i : burned-area
#
# i : fog-area
#
# i : fog-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : green-area
#
# i : fog-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : green-area
#
# i : burned-area
#
# i : green-area
#
# i : green-area
#
# i : green-area
#
# i : burned-area
#
# i : fog-area
#
# i : burned-area
#
# i : burned-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : fog-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : green-area
#
# i : fire-smoke
#
# i : green-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : green-area
#
# i : fire-smoke
#
# i : green-area
#
# i : green-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : fog-area
#
# i : green-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : fog-area
#
# i : green-area
#
# i : burned-area
#
# i : green-area
#
# i : green-area
#
# i : green-area
#
# i : burned-area
#
# i : burned-area
#
# i : green-area
#
# i : green-area
#
# i : fog-area
#
# i : green-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : fog-area
#
# i : green-area
#
# i : green-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : burned-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fog-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : green-area
#
# i : burned-area
#
# i : fog-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : green-area
#
# i : burned-area
#
# i : fog-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : burned-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : burned-area
#
# i : fog-area
#
# i : burned-area
#
# i : green-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : fog-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fog-area
#
# i : fire-smoke
#
# i : green-area
#
# i : fog-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : burned-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : green-area
#
# i : green-area
#
# i : green-area
#
# i : green-area
#
# i : burned-area
#
# i : green-area
#
# i : fire-smoke
#
# i : green-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : fire-smoke
#
# i : green-area
#
# i : green-area
#
# i : green-area
#
# i : fog-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : fire-smoke
#
# i : green-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : green-area
#
# i : burned-area
#
# i : fog-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : green-area
#
# i : fog-area
#
# i : burned-area
#
# i : green-area
#
# i : fog-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : green-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : green-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : green-area
#
# i : green-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : burned-area
#
# i : fog-area
#
# i : fog-area
#
# i : burned-area
#
# i : fog-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : green-area
#
# i : burned-area
#
# i : burned-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fog-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : burned-area
#
# i : fire-smoke
#
# i : green-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : green-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : burned-area
#
# i : burned-area
#
# i : green-area
#
# i : burned-area
#
# i : burned-area
#
# i : fog-area
#
# i : burned-area
#
# i : green-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : green-area
#
# i : fog-area
#
# i : green-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fog-area
#
# i : fog-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : burned-area
#
# i : burned-area
#
# i : green-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : fog-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fog-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : fog-area
#
# i : burned-area
#
# i : burned-area
#
# i : fog-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : fog-area
#
# i : burned-area
#
# i : fog-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : green-area
#
# i : fire-smoke
#
# i : green-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : fog-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fog-area
#
# i : burned-area
#
# i : fog-area
#
# i : burned-area
#
# i : burned-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : green-area
#
# i : green-area
#
# i : green-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fog-area
#
# i : fire-smoke
#
# i : green-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : burned-area
#
# i : fog-area
#
# i : burned-area
#
# i : fog-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : green-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fog-area
#
# i : burned-area
#
# i : green-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : fire-smoke
#
# i : green-area
#
# i : green-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : burned-area
#
# i : fog-area
#
# i : burned-area
#
# i : burned-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : green-area
#
# i : fog-area
#
# i : green-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : green-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fog-area
#
# i : green-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : fog-area
#
# i : green-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : green-area
#
# i : green-area
#
# i : fog-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : burned-area
#
# i : fog-area
#
# i : green-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : green-area
#
# i : fog-area
#
# i : burned-area
#
# i : green-area
#
# i : fire-smoke
#
# i : green-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : fog-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : green-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : green-area
#
# i : fog-area
#
# i : fog-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : fog-area
#
# i : fog-area
#
# i : fog-area
#
# i : green-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : fire-smoke
#
# i : green-area
#
# i : fire-smoke
#
# i : green-area
#
# i : burned-area
#
# i : burned-area
#
# i : fog-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : green-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : green-area
#
# i : burned-area
#
# i : fog-area
#
# i : green-area
#
# i : fog-area
#
# i : fog-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : burned-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : green-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : fog-area
#
# i : fog-area
#
# i : burned-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : fog-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : burned-area
#
# i : green-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : fog-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : burned-area
#
# i : fog-area
#
# i : fog-area
#
# i : green-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : burned-area
#
# i : green-area
#
# i : green-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : fire-smoke
#
# i : green-area
#
# i : burned-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : green-area
#
# i : fire-smoke
#
# i : green-area
#
# i : fog-area
#
# i : burned-area
#
# i : green-area
#
# i : fire-smoke
#
# i : green-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : burned-area
#
# i : green-area
#
# i : burned-area
#
# i : burned-area
#
# i : green-area
#
# i : green-area
#
# i : burned-area
#
# i : burned-area
#
# i : burned-area
#
# i : fog-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : fog-area
#
# i : fog-area
#
# i : burned-area
#
# i : burned-area
#
# i : burned-area
#
# i : fog-area
#
# i : burned-area
#
# i : green-area
#
# i : fog-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : green-area
#
# i : burned-area
#
# i : fog-area
#
# i : green-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fog-area
#
# i : fog-area
#
# i : fog-area
#
# i : green-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : fire-smoke
#
# i : green-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : fog-area
#
# i : fire-smoke
#
# i : green-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : fire-smoke
#
# i : green-area
#
# i : fog-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : green-area
#
# i : green-area
#
# i : green-area
#
# i : burned-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : green-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fog-area
#
# i : burned-area
#
# i : fog-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : burned-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : burned-area
#
# i : green-area
#
# i : fog-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : fog-area
#
# i : green-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : green-area
#
# i : fog-area
#
# i : green-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : fog-area
#
# i : fog-area
#
# i : burned-area
#
# i : burned-area
#
# i : burned-area
#
# i : green-area
#
# i : burned-area
#
# i : burned-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fog-area
#
# i : green-area
#
# i : burned-area
#
# i : green-area
#
# i : fog-area
#
# i : burned-area
#
# i : burned-area
#
# i : fog-area
#
# i : fog-area
#
# i : fog-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : burned-area
#
# i : green-area
#
# i : fog-area
#
# i : fog-area
#
# i : fog-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : burned-area
#
# i : green-area
#
# i : burned-area
#
# i : burned-area
#
# i : green-area
#
# i : fog-area
#
# i : green-area
#
# i : fog-area
#
# i : fire-smoke
#
# i : green-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : green-area
#
# i : green-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : green-area
#
# i : fog-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : burned-area
#
# i : green-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : burned-area
#
# i : burned-area
#
# i : fog-area
#
# i : fire-smoke
#
# i : green-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fog-area
#
# i : fire-smoke
#
# i : green-area
#
# i : fire-smoke
#
# i : green-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : green-area
#
# i : burned-area
#
# i : fog-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fog-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fog-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : burned-area
#
# i : green-area
#
# i : fog-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : burned-area
#
# i : fog-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : burned-area
#
# i : fog-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : green-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : burned-area
#
# i : fog-area
#
# i : fire-smoke
#
# i : green-area
#
# i : green-area
#
# i : green-area
#
# i : burned-area
#
# i : fog-area
#
# i : fire-smoke
#
# i : green-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : burned-area
#
# i : burned-area
#
# i : green-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : green-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : burned-area
#
# i : burned-area
#
# i : green-area
#
# i : green-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fog-area
#
# i : burned-area
#
# i : green-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : burned-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : burned-area
#
# i : green-area
#
# i : burned-area
#
# i : fog-area
#
# i : fire-smoke
#
# i : green-area
#
# i : burned-area
#
# i : green-area
#
# i : burned-area
#
# i : burned-area
#
# i : green-area
#
# i : green-area
#
# i : fog-area
#
# i : fire-smoke
#
# i : green-area
#
# i : fog-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : fire-smoke
#
# i : green-area
#
# i : green-area
#
# i : fog-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : green-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : burned-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : green-area
#
# i : fog-area
#
# i : green-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : burned-area
#
# i : green-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : burned-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : fog-area
#
# i : green-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : green-area
#
# i : burned-area
#
# i : green-area
#
# i : green-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : fog-area
#
# i : green-area
#
# i : burned-area
#
# i : fog-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : green-area
#
# i : green-area
#
# i : green-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : green-area
#
# i : burned-area
#
# i : fog-area
#
# i : burned-area
#
# i : fog-area
#
# i : fire-smoke
#
# i : green-area
#
# i : green-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : green-area
#
# i : burned-area
#
# i : fog-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : green-area
#
# i : fog-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : green-area
#
# i : burned-area
#
# i : fog-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fog-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : green-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : green-area
#
# i : burned-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : fog-area
#
# i : green-area
#
# i : green-area
#
# i : fog-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : fire-smoke
#
# i : green-area
#
# i : fog-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : green-area
#
# i : fog-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : green-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fog-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : burned-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : fog-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : green-area
#
# i : fog-area
#
# i : green-area
#
# i : green-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : green-area
#
# i : fog-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : green-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fog-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : green-area
#
# i : green-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : green-area
#
# i : fire-smoke
#
# i : green-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : burned-area
#
# i : fire-smoke
#
# i : green-area
#
# i : burned-area
#
# i : fog-area
#
# i : fire-smoke
#
# i : green-area
#
# i : green-area
#
# i : green-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : burned-area
#
# i : green-area
#
# i : burned-area
#
# i : green-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fog-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : burned-area
#
# i : burned-area
#
# i : green-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : fog-area
#
# i : fog-area
#
# i : green-area
#
# i : burned-area
#
# i : green-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : fog-area
#
# i : green-area
#
# i : green-area
#
# i : green-area
#
# i : fog-area
#
# i : fire-smoke
#
# i : green-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : fog-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : green-area
#
# i : fog-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : burned-area
#
# i : fog-area
#
# i : fog-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fog-area
#
# i : green-area
#
# i : green-area
#
# i : fog-area
#
# i : green-area
#
# i : green-area
#
# i : burned-area
#
# i : burned-area
#
# i : fog-area
#
# i : fire-smoke
#
# i : green-area
#
# i : green-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : fire-smoke
#
# i : green-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : green-area
#
# i : green-area
#
# i : fog-area
#
# i : green-area
#
# i : fog-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : fog-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : green-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : fog-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : burned-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : green-area
#
# i : burned-area
#
# i : burned-area
#
# i : fog-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : green-area
#
# i : green-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : green-area
#
# i : burned-area
#
# i : burned-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : green-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : green-area
#
# i : fog-area
#
# i : burned-area
#
# i : fog-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : green-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fog-area
#
# i : burned-area
#
# i : fog-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : green-area
#
# i : fog-area
#
# i : fog-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : burned-area
#
# i : fog-area
#
# i : fog-area
#
# i : green-area
#
# i : burned-area
#
# i : burned-area
#
# i : fog-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : burned-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fog-area
#
# i : fog-area
#
# i : fog-area
#
# i : burned-area
#
# i : burned-area
#
# i : burned-area
#
# i : green-area
#
# i : green-area
#
# i : burned-area
#
# i : burned-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : burned-area
#
# i : fog-area
#
# i : burned-area
#
# i : green-area
#
# i : green-area
#
# i : burned-area
#
# i : green-area
#
# i : green-area
#
# i : fog-area
#
# i : fire-smoke
#
# i : green-area
#
# i : burned-area
#
# i : fog-area
#
# i : green-area
#
# i : fog-area
#
# i : green-area
#
# i : green-area
#
# i : burned-area
#
# i : green-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : burned-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : burned-area
#
# i : burned-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : green-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : fog-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : burned-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : fog-area
#
# i : green-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : burned-area
#
# i : green-area
#
# i : fog-area
#
# i : fire-smoke
#
# i : green-area
#
# i : green-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : burned-area
#
# i : fire-smoke
#
# i : green-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : burned-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : fog-area
#
# i : green-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : burned-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : green-area
#
# i : burned-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : green-area
#
# i : fog-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fog-area
#
# i : green-area
#
# i : fog-area
#
# i : green-area
#
# i : fire-smoke
#
# i : burned-area
#
# i : burned-area
#
# i : green-area
#
# i : fog-area
#
# i : burned-area
#
# i : fog-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fog-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : green-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : fire-smoke
#
# i : green-area
#
# i : fog-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : burned-area
#
# i : green-area
#
# i : burned-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : green-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : burned-area
#
# i : fire-smoke
#
# i : fog-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fog-area
#
# i : burned-area
#
# i : burned-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : green-area
#
# i : fire-smoke
#
# i : fire-smoke
#
# i : burned-area
#
# i : green-area
#
# i : fog-area
#
# i : burned-area
#
# i : burned-area
#
# i : fog-area

# %%
templabel = np.array(test_label2)

# %% [markdown]
# #Function

# %%
# function to prediction
def classify_image(image):
    image = tf.reshape(image, (1, 224, 224, 3))
    classes = ["burned-area", "fire-smoke", "fog-area", "green-area"]#[0, 1, 2, 3]
    prediction = tf.keras.Model.predict(model, image, steps=1, batch_size=1)
    return classes[np.argmax(prediction[0])]

# %% [markdown]
# #Model

# %%
model = Sequential([
    Conv2D(filters=32, kernel_size=(3, 3), activation='relu', input_shape=(224, 224, 3)),
    MaxPooling2D(pool_size=(2, 2), strides=(2, 2)),
    Conv2D(filters=32, kernel_size=(3, 3), activation='relu'),
    MaxPooling2D(pool_size=(2, 2), strides=(4, 4)),
    Flatten(),
    Dense(units=64, activation='relu', kernel_initializer=GlorotUniform(seed=None), kernel_regularizer=l2()),
    Dropout(rate=0.2),
    Dense(units=64, activation='relu', kernel_initializer=GlorotUniform(seed=None), kernel_regularizer=l2()),
    Dropout(rate=0.2),
    Dense(units=4, activation='softmax', kernel_initializer=GlorotUniform(seed=None), kernel_regularizer=l2())
])

# %%
# Compile the model with an optimizer and loss function
import keras
optimizer = keras.optimizers.Adam(learning_rate=0.001)
loss_fn = keras.losses.SparseCategoricalCrossentropy()
model.compile(optimizer=optimizer, loss=loss_fn, metrics=['accuracy'])

# %%
model.load_weights("/content/drive/MyDrive/Image/Model/weight2_50epoch.h5")

# %%
# train_val_data, test_data, train_val_labels, test_labels = train_test_split(train_data2, train_y, test_size=0.5, random_state=42)
# train_data, val_data, train_labels, val_labels = train_test_split(train_data2,train_val_y, test_size=0.3, random_state=42)

# %%
# from collections import Counter

# %%
# Counter(train_labels), Counter(val_labels), Counter(test_y)

# %%
X_test = np.array(test_data2)

# %%
# X_train = np.array(train_data)
# X_test = np.array(test_data2)
# X_val = np.array(val_data)

# %%
# model.fit(X_train, train_labels, batch_size = 16, epochs=30,  validation_data=(X_val, val_labels))

# %%
# model.save("/content/drive/MyDrive/Image/Model/weight2_50epoch.h5")

# %%
test_data, batch1_data, test_labels, batch1_labels = train_test_split(X_test, templabel, test_size=0.1, random_state=42)
test_data, batch2_data, test_labels, batch2_labels = train_test_split(test_data, test_labels, test_size=0.1, random_state=42)
test_data, batch3_data, test_labels, batch3_labels = train_test_split(test_data, test_labels, test_size=0.1, random_state=42)
test_data, batch4_data, test_labels, batch4_labels = train_test_split(test_data, test_labels, test_size=0.1, random_state=42)
test_data, batch5_data, test_labels, batch5_labels = train_test_split(test_data, test_labels, test_size=0.1, random_state=42)
test_data, batch6_data, test_labels, batch6_labels = train_test_split(test_data, test_labels, test_size=0.1, random_state=42)
test_data, batch7_data, test_labels, batch7_labels = train_test_split(test_data, test_labels, test_size=0.1, random_state=42)
test_data, batch8_data, test_labels, batch8_labels = train_test_split(test_data, test_labels, test_size=0.1, random_state=42)
# test_data, batch9_data, test_labels, batch9_labels = train_test_split(test_data, test_labels, test_size=0.1, random_state=42)
# test_data, batch10_data, test_labels, batch10_labels = train_test_split(test_data, test_labels, test_size=0.1, random_state=42)
batch10_data, batch9_data, batch10_labels, batch9_labels = train_test_split(test_data, test_labels, test_size=0.1, random_state=42)

# %%
testData = [batch1_data, batch2_data, batch3_data, batch4_data, batch5_data ,batch6_data ,batch7_data, batch8_data, batch9_data, batch10_data]
testLabel = [batch1_labels, batch2_labels, batch3_labels, batch4_labels, batch5_labels ,batch6_labels ,batch7_labels, batch8_labels, batch9_labels, batch10_labels]

# %%
yTrue = []
yPred = []
for k in range(10):
  y_true = np.array([]) 
  y_pred = np.array([])
  tbatch = testData[k]
  tlabel = testLabel[k]
  for folder in range(len(tbatch)):
      # print("folder: ", folder)
      # pattern = "*.png"
      # if fnmatch.fnmatch(entry, pattern):
      predict = classify_image(tbatch[folder])
      real = tlabel[folder]
      print("predict: ", predict)
      print("real: ", real)
      y_true = np.append(y_true, real)
      y_pred = np.append(y_pred, predict)
  yTrue.append(y_true)
  yPred.append(y_pred)
# Out:
# Streaming output truncated to the last 5000 lines.
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 48ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 61ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 51ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 93ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 39ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 51ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 29ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 42ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 50ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 106ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 20ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 21ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 18ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 19ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 19ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 19ms/step
# predict:  green-area
# real:  burned-area
# 1/1 [==============================] - 0s 19ms/step
# predict:  green-area
# real:  burned-area
# 1/1 [==============================] - 0s 21ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 19ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 17ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 19ms/step
# predict:  fire-smoke
# real:  fog-area
# 1/1 [==============================] - 0s 19ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 26ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 18ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 26ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 19ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 18ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 26ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 28ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 37ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 26ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 31ms/step
# predict:  fog-area
# real:  fire-smoke
# 1/1 [==============================] - 0s 32ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 26ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 26ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 37ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 26ms/step
# predict:  fog-area
# real:  green-area
# 1/1 [==============================] - 0s 26ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 25ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 27ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 25ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 26ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 36ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 26ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 28ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 27ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 37ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 26ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 30ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 33ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 25ms/step
# predict:  fire-smoke
# real:  fog-area
# 1/1 [==============================] - 0s 31ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 26ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 25ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 26ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 26ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 34ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 26ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 25ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 27ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 30ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 29ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 26ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 32ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 30ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 32ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 26ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 26ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 43ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 25ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 27ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 31ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 28ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 29ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 26ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 25ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 26ms/step
# predict:  green-area
# real:  burned-area
# 1/1 [==============================] - 0s 34ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 27ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 19ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 25ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 22ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 29ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 24ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 20ms/step
# predict:  green-area
# real:  burned-area
# 1/1 [==============================] - 0s 18ms/step
# predict:  burned-area
# real:  fire-smoke
# 1/1 [==============================] - 0s 18ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 17ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 18ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 20ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 22ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 19ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 18ms/step
# predict:  burned-area
# real:  fire-smoke
# 1/1 [==============================] - 0s 21ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 17ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 23ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 22ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 18ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 32ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 22ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 23ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 22ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 23ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 24ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 19ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 20ms/step
# predict:  fog-area
# real:  fire-smoke
# 1/1 [==============================] - 0s 24ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 18ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 20ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 18ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 19ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 28ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 17ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 20ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 18ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 20ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 18ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 17ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 21ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 19ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 17ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 17ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 20ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 18ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 20ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 19ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 23ms/step
# predict:  burned-area
# real:  fire-smoke
# 1/1 [==============================] - 0s 25ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 22ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 22ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 19ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 24ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 19ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 20ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 23ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 17ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 21ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 19ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 20ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 29ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 18ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 18ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 19ms/step
# predict:  burned-area
# real:  fire-smoke
# 1/1 [==============================] - 0s 18ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 21ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 19ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 17ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 19ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 20ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 20ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 22ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 24ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 18ms/step
# predict:  green-area
# real:  fire-smoke
# 1/1 [==============================] - 0s 19ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 21ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 20ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 18ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 22ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 21ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 19ms/step
# predict:  fog-area
# real:  green-area
# 1/1 [==============================] - 0s 21ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 18ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 20ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 22ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 20ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 25ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 19ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 18ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 19ms/step
# predict:  green-area
# real:  fire-smoke
# 1/1 [==============================] - 0s 21ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 19ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 23ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 20ms/step
# predict:  burned-area
# real:  fire-smoke
# 1/1 [==============================] - 0s 33ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 23ms/step
# predict:  green-area
# real:  burned-area
# 1/1 [==============================] - 0s 23ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 21ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 20ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 21ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 20ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 19ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 21ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 24ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 18ms/step
# predict:  burned-area
# real:  fire-smoke
# 1/1 [==============================] - 0s 20ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 23ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 21ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 22ms/step
# predict:  green-area
# real:  fire-smoke
# 1/1 [==============================] - 0s 21ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 19ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 20ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 24ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 20ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 19ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 18ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 21ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 23ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 21ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 21ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 19ms/step
# predict:  fog-area
# real:  burned-area
# 1/1 [==============================] - 0s 19ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 21ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 40ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 22ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 19ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 23ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 26ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 19ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 18ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 23ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 22ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 21ms/step
# predict:  burned-area
# real:  fire-smoke
# 1/1 [==============================] - 0s 18ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 18ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 18ms/step
# predict:  fog-area
# real:  green-area
# 1/1 [==============================] - 0s 22ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 20ms/step
# predict:  burned-area
# real:  fire-smoke
# 1/1 [==============================] - 0s 20ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 22ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 20ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 18ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 17ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 18ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 21ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 22ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 23ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 22ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 18ms/step
# predict:  burned-area
# real:  fire-smoke
# 1/1 [==============================] - 0s 35ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 34ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 33ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 34ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 29ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 32ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 26ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 25ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 27ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 26ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 49ms/step
# predict:  fog-area
# real:  green-area
# 1/1 [==============================] - 0s 50ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 44ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 27ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 34ms/step
# predict:  green-area
# real:  fog-area
# 1/1 [==============================] - 0s 35ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 25ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 24ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 35ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 26ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 37ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 26ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 31ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 28ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 36ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 36ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 32ms/step
# predict:  fog-area
# real:  fire-smoke
# 1/1 [==============================] - 0s 37ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 30ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 30ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 41ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 33ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 35ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 24ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 43ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 31ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 34ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 28ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 34ms/step
# predict:  burned-area
# real:  green-area
# 1/1 [==============================] - 0s 39ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 28ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 27ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 33ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 30ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 26ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 32ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 30ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 35ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 27ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 32ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 31ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 54ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 25ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 25ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 51ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 20ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 19ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 21ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 19ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 17ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 21ms/step
# predict:  green-area
# real:  burned-area
# 1/1 [==============================] - 0s 18ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 18ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 18ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 19ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 23ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 20ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 18ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 20ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 17ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 19ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 20ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 20ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 21ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 19ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 18ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 19ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 20ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 21ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 17ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 20ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 28ms/step
# predict:  burned-area
# real:  green-area
# 1/1 [==============================] - 0s 21ms/step
# predict:  fog-area
# real:  green-area
# 1/1 [==============================] - 0s 20ms/step
# predict:  fog-area
# real:  burned-area
# 1/1 [==============================] - 0s 18ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 23ms/step
# predict:  burned-area
# real:  fire-smoke
# 1/1 [==============================] - 0s 24ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 22ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 20ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 19ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 18ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 26ms/step
# predict:  burned-area
# real:  green-area
# 1/1 [==============================] - 0s 23ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 23ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 18ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 17ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 22ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 20ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 18ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 20ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 22ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 18ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 21ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 25ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 20ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 18ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 25ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 20ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 23ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 24ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 18ms/step
# predict:  burned-area
# real:  fire-smoke
# 1/1 [==============================] - 0s 20ms/step
# predict:  burned-area
# real:  green-area
# 1/1 [==============================] - 0s 19ms/step
# predict:  green-area
# real:  burned-area
# 1/1 [==============================] - 0s 26ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 22ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 20ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 20ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 22ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 18ms/step
# predict:  burned-area
# real:  fire-smoke
# 1/1 [==============================] - 0s 20ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 25ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 21ms/step
# predict:  fog-area
# real:  burned-area
# 1/1 [==============================] - 0s 25ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 22ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 20ms/step
# predict:  burned-area
# real:  fire-smoke
# 1/1 [==============================] - 0s 21ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 18ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 21ms/step
# predict:  green-area
# real:  burned-area
# 1/1 [==============================] - 0s 21ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 26ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 23ms/step
# predict:  burned-area
# real:  fire-smoke
# 1/1 [==============================] - 0s 19ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 20ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 19ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 18ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 19ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 20ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 19ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 22ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 21ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 21ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 27ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 22ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 22ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 21ms/step
# predict:  fire-smoke
# real:  burned-area
# 1/1 [==============================] - 0s 19ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 19ms/step
# predict:  burned-area
# real:  fire-smoke
# 1/1 [==============================] - 0s 18ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 18ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 21ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 21ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 25ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 30ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 20ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 19ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 18ms/step
# predict:  burned-area
# real:  fire-smoke
# 1/1 [==============================] - 0s 19ms/step
# predict:  burned-area
# real:  fog-area
# 1/1 [==============================] - 0s 19ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 27ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 20ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 22ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 19ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 20ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 22ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 18ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 21ms/step
# predict:  fire-smoke
# real:  fog-area
# 1/1 [==============================] - 0s 24ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 23ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 23ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 25ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 23ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 31ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 20ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 20ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 19ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 18ms/step
# predict:  burned-area
# real:  fire-smoke
# 1/1 [==============================] - 0s 19ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 22ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 25ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 22ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 25ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 22ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 21ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 25ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 21ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 24ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 26ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 21ms/step
# predict:  burned-area
# real:  fire-smoke
# 1/1 [==============================] - 0s 18ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 21ms/step
# predict:  fog-area
# real:  fire-smoke
# 1/1 [==============================] - 0s 29ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 21ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 24ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 26ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 21ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 20ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 26ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 18ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 18ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 18ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 77ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 165ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 149ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 27ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 27ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 33ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 27ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 34ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 42ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 26ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 36ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 32ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 38ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 27ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 39ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 34ms/step
# predict:  fire-smoke
# real:  burned-area
# 1/1 [==============================] - 0s 30ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 42ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 29ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 37ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 26ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 28ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 51ms/step
# predict:  burned-area
# real:  green-area
# 1/1 [==============================] - 0s 30ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 27ms/step
# predict:  fire-smoke
# real:  fog-area
# 1/1 [==============================] - 0s 26ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 24ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 26ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 27ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 32ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 36ms/step
# predict:  burned-area
# real:  fire-smoke
# 1/1 [==============================] - 0s 26ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 28ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 45ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 50ms/step
# predict:  green-area
# real:  burned-area
# 1/1 [==============================] - 0s 35ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 27ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 55ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 30ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 24ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 39ms/step
# predict:  burned-area
# real:  fire-smoke
# 1/1 [==============================] - 0s 38ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 35ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 32ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 35ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 41ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 54ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 34ms/step
# predict:  burned-area
# real:  fire-smoke
# 1/1 [==============================] - 0s 35ms/step
# predict:  fire-smoke
# real:  fog-area
# 1/1 [==============================] - 0s 26ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 25ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 29ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 25ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 28ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 24ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 22ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 25ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 21ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 22ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 18ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 17ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 19ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 17ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 21ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 23ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 21ms/step
# predict:  burned-area
# real:  fire-smoke
# 1/1 [==============================] - 0s 21ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 24ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 21ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 26ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 27ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 21ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 23ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 18ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 18ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 26ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 23ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 22ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 28ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 22ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 22ms/step
# predict:  fog-area
# real:  green-area
# 1/1 [==============================] - 0s 31ms/step
# predict:  green-area
# real:  fire-smoke
# 1/1 [==============================] - 0s 22ms/step
# predict:  burned-area
# real:  green-area
# 1/1 [==============================] - 0s 20ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 23ms/step
# predict:  fire-smoke
# real:  fog-area
# 1/1 [==============================] - 0s 23ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 22ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 23ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 21ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 21ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 23ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 19ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 20ms/step
# predict:  burned-area
# real:  fire-smoke
# 1/1 [==============================] - 0s 28ms/step
# predict:  burned-area
# real:  fog-area
# 1/1 [==============================] - 0s 19ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 25ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 22ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 20ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 22ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 23ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 20ms/step
# predict:  green-area
# ...
# 1/1 [==============================] - 0s 22ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 24ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 24ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 23ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 23ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 22ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 20ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 26ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 24ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 24ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 26ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 22ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 22ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 26ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 22ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 24ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 28ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 29ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 27ms/step
# predict:  burned-area
# real:  fire-smoke
# 1/1 [==============================] - 0s 30ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 26ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 31ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 27ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 24ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 27ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 30ms/step
# predict:  fog-area
# real:  burned-area
# 1/1 [==============================] - 0s 29ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 28ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 27ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 26ms/step
# predict:  fog-area
# real:  fire-smoke
# 1/1 [==============================] - 0s 24ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 27ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 25ms/step
# predict:  fog-area
# real:  fire-smoke
# 1/1 [==============================] - 0s 32ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 26ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 23ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 30ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 32ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 27ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 27ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 28ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 28ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 28ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 27ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 30ms/step
# predict:  fog-area
# real:  green-area
# 1/1 [==============================] - 0s 23ms/step
# predict:  burned-area
# real:  fog-area
# 1/1 [==============================] - 0s 25ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 29ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 28ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 31ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 33ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 29ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 24ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 34ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 32ms/step
# predict:  fog-area
# real:  fire-smoke
# 1/1 [==============================] - 0s 25ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 27ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 25ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 29ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 27ms/step
# predict:  fog-area
# real:  fire-smoke
# 1/1 [==============================] - 0s 29ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 25ms/step
# predict:  burned-area
# real:  fog-area
# 1/1 [==============================] - 0s 25ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 25ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 25ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 36ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 39ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 28ms/step
# predict:  burned-area
# real:  fire-smoke
# 1/1 [==============================] - 0s 28ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 36ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 33ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 33ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 32ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 29ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 33ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 40ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 32ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 42ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 39ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 44ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 30ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 60ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 48ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 42ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 41ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 46ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 43ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 45ms/step
# predict:  fog-area
# real:  fire-smoke
# 1/1 [==============================] - 0s 38ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 42ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 53ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 46ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 38ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 30ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 37ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 49ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 43ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 28ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 38ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 28ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 64ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 60ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 63ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 62ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 41ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 39ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 31ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 46ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 62ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 41ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 51ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 33ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 33ms/step
# predict:  burned-area
# real:  green-area
# 1/1 [==============================] - 0s 52ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 55ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 34ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 51ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 45ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 30ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 48ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 54ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 30ms/step
# predict:  burned-area
# real:  fog-area
# 1/1 [==============================] - 0s 27ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 28ms/step
# predict:  burned-area
# real:  green-area
# 1/1 [==============================] - 0s 30ms/step
# predict:  green-area
# real:  burned-area
# 1/1 [==============================] - 0s 26ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 27ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 27ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 36ms/step
# predict:  burned-area
# real:  fire-smoke
# 1/1 [==============================] - 0s 28ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 27ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 26ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 30ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 31ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 29ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 28ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 27ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 25ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 30ms/step
# predict:  green-area
# real:  burned-area
# 1/1 [==============================] - 0s 28ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 27ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 44ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 30ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 26ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 37ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 21ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 25ms/step
# predict:  green-area
# real:  burned-area
# 1/1 [==============================] - 0s 20ms/step
# predict:  green-area
# real:  burned-area
# 1/1 [==============================] - 0s 28ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 38ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 23ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 32ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 24ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 25ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 31ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 37ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 20ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 25ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 23ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 30ms/step
# predict:  fog-area
# real:  fire-smoke
# 1/1 [==============================] - 0s 28ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 24ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 26ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 25ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 21ms/step
# predict:  fire-smoke
# real:  fire-smoke
# 1/1 [==============================] - 0s 25ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 27ms/step
# predict:  fog-area
# real:  fire-smoke
# 1/1 [==============================] - 0s 21ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 28ms/step
# predict:  green-area
# real:  green-area
# 1/1 [==============================] - 0s 25ms/step
# predict:  fog-area
# real:  fog-area
# 1/1 [==============================] - 0s 26ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 25ms/step
# predict:  fog-area
# real:  burned-area
# 1/1 [==============================] - 0s 27ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 23ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 28ms/step
# predict:  burned-area
# real:  burned-area
# 1/1 [==============================] - 0s 32ms/step
# predict:  fog-area
# real:  fog-area

# %%
# yPred[0], yTrue[0]

# %%
target_names = ["burned-area", "fire-smoke", "fog-area", "green-area"]
for i in range(10):
  print("Fold ",i,": ")
  # target_names = ["Non-Smoke", "Non-Smoke+Fog", "Smoke", "Smoke+Fog"]    # CCTV dataset
   # UAV dataset
  print(classification_report(yTrue[i], yPred[i], target_names=target_names))
# Out:
# Fold  0 :
#               precision    recall  f1-score   support
#
#  burned-area       0.87      0.89      0.88        62
#   fire-smoke       0.96      0.85      0.90        79
#     fog-area       0.88      0.92      0.90        49
#   green-area       0.82      0.93      0.87        45
#
#     accuracy                           0.89       235
#    macro avg       0.88      0.90      0.89       235
# weighted avg       0.89      0.89      0.89       235
#
# Fold  1 :
#               precision    recall  f1-score   support
#
#  burned-area       0.84      1.00      0.91        51
#   fire-smoke       0.93      0.83      0.88        60
#     fog-area       0.90      0.79      0.84        47
#   green-area       0.93      0.96      0.94        53
#
#     accuracy                           0.90       211
#    macro avg       0.90      0.90      0.89       211
# weighted avg       0.90      0.90      0.89       211
#
# Fold  2 :
#               precision    recall  f1-score   support
#
#  burned-area       0.90      0.92      0.91        50
#   fire-smoke       0.98      0.83      0.90        58
#     fog-area       0.95      0.97      0.96        36
#   green-area       0.85      0.98      0.91        46
#
#     accuracy                           0.92       190
#    macro avg       0.92      0.92      0.92       190
# weighted avg       0.92      0.92      0.92       190
#
# Fold  3 :
#               precision    recall  f1-score   support
#
#  burned-area       0.90      0.88      0.89        41
#   fire-smoke       0.95      0.91      0.93        67
#     fog-area       0.89      0.91      0.90        34
#   green-area       0.88      0.97      0.92        29
#
#     accuracy                           0.91       171
#    macro avg       0.90      0.92      0.91       171
# weighted avg       0.91      0.91      0.91       171
#
# Fold  4 :
#               precision    recall  f1-score   support
#
#  burned-area       0.84      0.95      0.89        38
#   fire-smoke       1.00      0.83      0.91        59
#     fog-area       0.87      0.97      0.92        35
#   green-area       0.78      0.82      0.80        22
#
#     accuracy                           0.89       154
#    macro avg       0.87      0.89      0.88       154
# weighted avg       0.90      0.89      0.89       154
#
# Fold  5 :
#               precision    recall  f1-score   support
#
#  burned-area       0.72      0.85      0.78        40
#   fire-smoke       0.95      0.79      0.86        48
#     fog-area       0.85      0.92      0.88        25
#   green-area       0.88      0.85      0.86        26
#
#     accuracy                           0.84       139
#    macro avg       0.85      0.85      0.85       139
# weighted avg       0.85      0.84      0.84       139
#
# Fold  6 :
#               precision    recall  f1-score   support
#
#  burned-area       0.75      0.92      0.83        26
#   fire-smoke       0.90      0.86      0.88        42
#     fog-area       0.93      0.83      0.88        30
#   green-area       0.88      0.85      0.87        27
#
#     accuracy                           0.86       125
#    macro avg       0.87      0.87      0.86       125
# weighted avg       0.87      0.86      0.87       125
#
# Fold  7 :
#               precision    recall  f1-score   support
#
#  burned-area       0.86      0.83      0.84        29
#   fire-smoke       0.98      0.86      0.91        50
#     fog-area       0.74      0.88      0.80        16
#   green-area       0.71      0.88      0.79        17
#
#     accuracy                           0.86       112
#    macro avg       0.82      0.86      0.84       112
# weighted avg       0.87      0.86      0.86       112
#
# Fold  8 :
#               precision    recall  f1-score   support
#
#  burned-area       0.81      0.94      0.87        31
#   fire-smoke       0.95      0.71      0.82        28
#     fog-area       1.00      0.95      0.97        19
#   green-area       0.88      1.00      0.94        23
#
#     accuracy                           0.89       101
#    macro avg       0.91      0.90      0.90       101
# weighted avg       0.90      0.89      0.89       101
#
# Fold  9 :
#               precision    recall  f1-score   support
#
#  burned-area       0.85      0.89      0.87       252
#   fire-smoke       0.92      0.86      0.89       280
#     fog-area       0.85      0.89      0.87       192
#   green-area       0.89      0.87      0.88       180
#
#     accuracy                           0.88       904
#    macro avg       0.88      0.88      0.88       904
# weighted avg       0.88      0.88      0.88       904

# %%
hamm = []
acc = []
p = []
r = []
f1 = []
for i in range(10):
  print("-----------------------------------------")
  print("Fold ",i,": ")

  hammingLoss = hamming_loss(yTrue[i], yPred[i])
  hamm.append(hammingLoss )
  print("Hamming loss: %f" % hammingLoss)
  Accuracy = metrics.accuracy_score(yTrue[i], yPred[i])
  acc.append(Accuracy)
  print("Accuracy: %f" % Accuracy)
  PrecisionMacro = metrics.precision_score(yTrue[i], yPred[i], average='macro')
  p.append(PrecisionMacro)
  print("Precision Macro: %f" % PrecisionMacro)
  RecallMacro = metrics.recall_score(yTrue[i], yPred[i], average='macro')
  r.append(RecallMacro)
  print("Recall Macro: %f" % RecallMacro)
  F1score = metrics.f1_score(yTrue[i], yPred[i], average='weighted')
  f1.append(F1score)
  print("F1-score: %f" % F1score)
  print("-----------------------------------------")
# Out:
# -----------------------------------------
# Fold  0 :
# Hamming loss: 0.110638
# Accuracy: 0.889362
# Precision Macro: 0.884010
# Recall Macro: 0.896725
# F1-score: 0.889711
# -----------------------------------------
# -----------------------------------------
# Fold  1 :
# Hamming loss: 0.104265
# Accuracy: 0.895735
# Precision Macro: 0.897926
# Recall Macro: 0.895708
# F1-score: 0.894106
# -----------------------------------------
# -----------------------------------------
# Fold  2 :
# Hamming loss: 0.084211
# Accuracy: 0.915789
# Precision Macro: 0.919139
# Recall Macro: 0.924517
# F1-score: 0.915372
# -----------------------------------------
# -----------------------------------------
# Fold  3 :
# Hamming loss: 0.087719
# Accuracy: 0.912281
# Precision Macro: 0.903460
# Recall Macro: 0.916445
# F1-score: 0.912369
# -----------------------------------------
# -----------------------------------------
# Fold  4 :
# Hamming loss: 0.110390
# Accuracy: 0.889610
# Precision Macro: 0.872903
# Recall Macro: 0.891872
# F1-score: 0.890110
# -----------------------------------------
# -----------------------------------------
# Fold  5 :
# Hamming loss: 0.158273
# Accuracy: 0.841727
# Precision Macro: 0.851314
# Recall Macro: 0.851955
# F1-score: 0.843638
# -----------------------------------------
# -----------------------------------------
# Fold  6 :
# Hamming loss: 0.136000
# Accuracy: 0.864000
# Precision Macro: 0.865135
# Recall Macro: 0.866351
# F1-score: 0.865160
# -----------------------------------------
# -----------------------------------------
# Fold  7 :
# Hamming loss: 0.142857
# Accuracy: 0.857143
# Precision Macro: 0.821386
# Recall Macro: 0.861235
# F1-score: 0.860596
# -----------------------------------------
# -----------------------------------------
# Fold  8 :
# Hamming loss: 0.108911
# Accuracy: 0.891089
# Precision Macro: 0.910638
# Recall Macro: 0.899285
# F1-score: 0.888825
# -----------------------------------------
# -----------------------------------------
# Fold  9 :
# Hamming loss: 0.120575
# Accuracy: 0.879425
# Precision Macro: 0.878682
# Recall Macro: 0.879998
# F1-score: 0.879656
# -----------------------------------------

# %%
print(np.mean(hamm))
print(np.mean(acc))
print(np.mean(p))
print(np.mean(r))
print(np.mean(f1))
# Out:
# 0.11638397721471101
# 0.883616022785289
# 0.8804592687642832
# 0.8884089507988703
# 0.883954210097958

# %% [markdown]
# Dataset1

# %%
tf.device('/gpu:0')
dir = "/content/drive/MyDrive/Image/Dataset1/"
test_dir = dir
label = []
list_of_folders = os.listdir(test_dir)
frame_paths = []

for folder in list_of_folders:
    print("folder: ", folder)
    list_of_files = os.listdir(test_dir + "/" + folder)
    pattern = "*.jpg"
    counter = 0
    for entry in list_of_files:
        if fnmatch.fnmatch(entry, pattern):
            file_path = test_dir + folder + "/" + entry
            frame_paths.append(file_path)
            label.append(folder)
# Out:
# folder:  Non-Smoke
# folder:  Non-Smoke + Fog
# folder:  Smoke
# folder:  Smoke + Fog

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

numerical_labels = le.fit_transform(label)

for label, num in zip(le.classes_, le.transform(le.classes_)):
    print(f"{label} : {num}")
train_y = np.array(numerical_labels)
# Out:
# Non-Smoke : 0
# Non-Smoke + Fog : 1
# Smoke : 2
# Smoke + Fog : 3

# %%
len(frame_paths)
# Out:
# 72039

# %%
train_val_data, test_data, train_val_labels, test_labels = train_test_split(frame_paths, train_y, test_size=0.5, random_state=42)
train_data, val_data, train_labels, val_labels = train_test_split(train_val_data, train_val_labels, test_size=0.3, random_state=42)

# %%
tf.device('/gpu:0')
train_test = []
train_label_test = []
counter = 0
for i in train_data:
    if(counter==1400):
      break

    file_path = i
    image = tf.io.read_file(file_path)
    # print("image1: ", image)
    # start_time = tm.time()
    image = tf.image.decode_png(image, channels=3)
    # print("image2: ", image)
    image = tf.cast(image, tf.float32) * (1. / 255)
    # print("image3: ", image)
    # image = tf.image.convert_image_dtype(img_name, tf.float32)
    image = tf.image.resize(image, [224, 224])
    # print("image4: ", image)
    image = tf.reshape(image, (224, 224, 3))
    # print("image.shape: ", image.shape)
    train_test.append(image)
    train_label_test.append(train_labels[counter])
    counter+=1

# %%
tf.device('/gpu:0')
test_test = []
test_label_test = []
counter =0 
for i in test_data:
    if(counter == 2000):
      break
    # counter+=1
    file_path = i
    image = tf.io.read_file(file_path)
    # print("image1: ", image)
    # start_time = tm.time()
    image = tf.image.decode_png(image, channels=3)
    # print("image2: ", image)
    image = tf.cast(image, tf.float32) * (1. / 255)
    # print("image3: ", image)
    # image = tf.image.convert_image_dtype(img_name, tf.float32)
    image = tf.image.resize(image, [224, 224])
    # print("image4: ", image)
    image = tf.reshape(image, (224, 224, 3))
    # print("image.shape: ", image.shape)
    test_test.append(image)
    test_label_test.append(test_labels[counter])
    counter+=1

# %%
tf.device('/gpu:0')
val_test = []
val_label_test = []
counter =0 
for i in val_data:
    if(counter == 600):
      break
    # counter+=1
    file_path = i
    image = tf.io.read_file(file_path)
    # print("image1: ", image)
    # start_time = tm.time()
    image = tf.image.decode_png(image, channels=3)
    # print("image2: ", image)
    image = tf.cast(image, tf.float32) * (1. / 255)
    # print("image3: ", image)
    # image = tf.image.convert_image_dtype(img_name, tf.float32)
    image = tf.image.resize(image, [224, 224])
    # print("image4: ", image)
    image = tf.reshape(image, (224, 224, 3))
    # print("image.shape: ", image.shape)
    val_test.append(image)
    val_label_test.append(val_labels[counter])
    counter+=1

# %%
X = np.array(train_test)
y = np.array(train_label_test)
X_val = np.array(val_test)
y_val = np.array(val_label_test)
X_test = np.array(test_test)
y_test = np.array(test_label_test)

# %%
optimizer = keras.optimizers.Adam(learning_rate=0.001)
loss_fn = keras.losses.SparseCategoricalCrossentropy()
model.compile(optimizer=optimizer, loss=loss_fn, metrics=['accuracy'])

# %%
model.fit(X, y, epochs=100,  validation_data=(X_val, y_val))

# %%
# dir = "/home/jefferson/DOUTORADO2/DatasetDrone/test/10/" # load path with test images
dir = "/content/drive/MyDrive/Image/"
test_dir = dir + "Test2"
# listOfFolders = os.listdir(test_dir)
# print("listOfFolders: ", listOfFolders)
y_true = np.array([])  # y_true = [] list
y_pred = np.array([])
# predictTime = np.array([])
predictTime = []
cont = 0
for folder in range(len(X_test)):
    # print("folder: ", folder)
    # listOfFiles = os.listdir(test_dir + "/" + folder)
    # print("listOfFiles: ", listOfFiles)
    pattern = "*.jpg"
    # for entry in listOfFiles:
        # print("entry: ", entry)
    if fnmatch.fnmatch(entry, pattern):
      # dir2 = test_dir+"/" + folder + "/"
            # print("dir2: ", dir2)
            # start_time = time.time()
            # predict, time = classify_image(entry, dir2)
      # print("test_data[folder]: ", test_data[folder])
      predict = classify_image(X_test[folder])
            # print("predict: ", predict)
            # predictTime = np.append(predictTime, time)  # predictTime.append(time.time() - start_time)
            # predictTime.append(time)
      real = y_test[folder]
      print("predict: ", predict)
      print("real: ", real)
      # resultado = "Real: " + real + "  Predicao: " + predict
      # print(resultado)
      y_true = np.append(y_true, real)  # y_true.append(real)
      y_pred = np.append(y_pred, predict)  # y_pred.append(predict)

# %%
target_names = ["Non-Smoke", "Non-Smoke+Fog", "Smoke", "Smoke+Fog"]    # CCTV dataset
# target_names = ["burned-area", "fire-smoke", "fog-area", "green-area"]   # UAV dataset
print(classification_report(y_true, y_pred, target_names=target_names))

# %%
hammingLoss = hamming_loss(y_true, y_pred)
print("Hamming loss: %f" % hammingLoss)
Accuracy = metrics.accuracy_score(y_true, y_pred)
print("Accuracy: %f" % Accuracy)
PrecisionMacro = metrics.precision_score(y_true, y_pred, average='macro')
print("Precision Macro: %f" % PrecisionMacro)
RecallMacro = metrics.recall_score(y_true, y_pred, average='macro')
print("Recall Macro: %f" % RecallMacro)
F1score = metrics.f1_score(y_true, y_pred, average='weighted')
print("F1-score: %f" % F1score)

# %%
optimizer = keras.optimizers.Adam(learning_rate=0.001)
loss_fn = keras.losses.SparseCategoricalCrossentropy()
model.compile(optimizer=optimizer, loss=loss_fn, metrics=['accuracy'])

# %%
model.fit(X, y, epochs=10,  validation_data=(X_val, y_val))

# %%
# dir = "/home/jefferson/DOUTORADO2/DatasetDrone/test/10/" # load path with test images
dir = "/content/drive/MyDrive/Image/"
test_dir = dir + "Test2"
# listOfFolders = os.listdir(test_dir)
# print("listOfFolders: ", listOfFolders)
y_true = np.array([])  # y_true = [] list
y_pred = np.array([])
# predictTime = np.array([])
predictTime = []
cont = 0
for folder in range(len(X_test)):
    # print("folder: ", folder)
    # listOfFiles = os.listdir(test_dir + "/" + folder)
    # print("listOfFiles: ", listOfFiles)
    pattern = "*.jpg"
    # for entry in listOfFiles:
        # print("entry: ", entry)
    if fnmatch.fnmatch(entry, pattern):
      # dir2 = test_dir+"/" + folder + "/"
            # print("dir2: ", dir2)
            # start_time = time.time()
            # predict, time = classify_image(entry, dir2)
      # print("test_data[folder]: ", test_data[folder])
      predict = classify_image(X_test[folder])
            # print("predict: ", predict)
            # predictTime = np.append(predictTime, time)  # predictTime.append(time.time() - start_time)
            # predictTime.append(time)
      real = y_test[folder]
      print("predict: ", predict)
      print("real: ", real)
      # resultado = "Real: " + real + "  Predicao: " + predict
      # print(resultado)
      y_true = np.append(y_true, real)  # y_true.append(real)
      y_pred = np.append(y_pred, predict)  # y_pred.append(predict)

# %%
target_names = ["Non-Smoke", "Non-Smoke+Fog", "Smoke", "Smoke+Fog"]    # CCTV dataset
# target_names = ["burned-area", "fire-smoke", "fog-area", "green-area"]   # UAV dataset
print(classification_report(y_true, y_pred, target_names=target_names))

# %%
hammingLoss = hamming_loss(y_true, y_pred)
print("Hamming loss: %f" % hammingLoss)
Accuracy = metrics.accuracy_score(y_true, y_pred)
print("Accuracy: %f" % Accuracy)
PrecisionMacro = metrics.precision_score(y_true, y_pred, average='macro')
print("Precision Macro: %f" % PrecisionMacro)
RecallMacro = metrics.recall_score(y_true, y_pred, average='macro')
print("Recall Macro: %f" % RecallMacro)
F1score = metrics.f1_score(y_true, y_pred, average='weighted')
print("F1-score: %f" % F1score)
